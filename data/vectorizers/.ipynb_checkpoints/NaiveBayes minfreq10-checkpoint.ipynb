# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
df = pd.read_json('../train/trainText75.json', lines=True)

# %%
ingredients = {}
for lst in df['ingredients']:
    for i in lst:
        i = i.replace(' ','_').strip('_')
        if not i in ingredients:
            ingredients[i] = 1
        else:
            ingredients[i] += 1

# %%
ingredients['black_olives']
# Out:
# 476

# %%
MIN_FREQUENCY = 10
filtered_ingredients = {k: v for k, v in ingredients.items() if v >= MIN_FREQUENCY}

# %%
recipes = list(df['recipe'])
labels = list(df['cuisine'])

# %%
vectorizer = CountVectorizer()
vectorizer.fit(filtered_ingredients.keys())
print('Number of Features: %d'%len(vectorizer.get_feature_names()))
# Out:
# Number of Features: 3410

# %%
print(vectorizer.get_feature_names())
# Out:
# ['____oz', '_chopped_green_chiles', '_classico_olive_oil', '_cooked_and_drained', '_crush', '_drain', '_drained_and_chopped', '_fine_chop', '_half', '_low', '_or_best_food_light_mayonnais', '_or_best_food_real_mayonnais', '_peel_and_devein', '_reduced', '_refrigerated_crescent_dinner_rolls', '_rins_and_drain', '_skinless_chicken_breast', '_slice', '_soften', '_spread', '_taco_seasoning_mix', '_thawed_and_squeezed_dry', '_tomato_sauce', 'achiote_paste', 'acorn_squash', 'acting_baking_powder', 'active_dry_yeast', 'added_black_beans', 'added_diced_tomatoes', 'adobo', 'adobo_sauce', 'adobo_seasoning', 'agave_nectar', 'aged_balsamic_vinegar', 'aioli', 'ajwain', 'ale', 'aleppo_pepper', 'alfredo_sauce', 'all', 'all_purpose_unbleached_flour', 'allspice', 'allspice_berries', 'almond_butter', 'almond_extract', 'almond_flour', 'almond_meal', 'almond_milk', 'almond_paste', 'almonds', 'amaretti_cookies', 'amaretto', 'amchur', 'american_cheese', 'anaheim_chile', 'ancho', 'ancho_chile_pepper', 'ancho_chili_ground_pepper', 'ancho_powder', 'anchovies', 'anchovy_fillets', 'anchovy_paste', 'and_fat_free_half_half', 'andouille_sausage', 'angel_hair', 'angostura_bitters', 'anise', 'anise_extract', 'anise_seed', 'annatto_seeds', 'apple_cider', 'apple_cider_vinegar', 'apple_juice', 'apples', 'applesauce', 'applewood_smoked_bacon', 'apricot_halves', 'apricot_jam', 'apricot_preserves', 'apricots', 'arbol_chile', 'arborio_rice', 'armagnac', 'arrowroot', 'arrowroot_powder', 'artichok_heart_marin', 'artichoke_hearts', 'artichokes', 'arugula', 'asadero', 'asafetida', 'asafoetida', 'asafoetida_powder', 'asiago', 'asian_eggplants', 'asian_fish_sauce', 'asian_pear', 'asparagus', 'asparagus_spears', 'atta', 'avocado', 'avocado_oil', 'açai', 'baby_arugula', 'baby_back_ribs', 'baby_bok_choy', 'baby_carrots', 'baby_corn', 'baby_greens', 'baby_lima_beans', 'baby_portobello_mushrooms', 'baby_potatoes', 'baby_spinach', 'baby_spinach_leaves', 'baby_zucchini', 'bacon', 'bacon_drippings', 'bacon_fat', 'bacon_grease', 'bacon_slices', 'baguette', 'baileys_irish_cream_liqueur', 'baked_ham', 'baked_pizza_crust', 'baked_tortilla_chips', 'baking_mix', 'baking_potatoes', 'baking_powder', 'baking_soda', 'balsamic_vinaigrette', 'balsamic_vinegar', 'bamboo_shoots', 'banana_leaves', 'banana_peppers', 'bananas', 'barbecue_sauce', 'barbecued_pork', 'bartlett_pears', 'base', 'basil', 'basil_dried_leaves', 'basil_leaves', 'basil_pesto_sauce', 'basmati_rice', 'bawang_goreng', 'bay_leaf', 'bay_leaves', 'bay_scallops', 'bbq_sauce', 'bean_curd', 'bean_paste', 'bean_sauce', 'bean_threads', 'beans', 'beansprouts', 'beaten_eggs', 'beef', 'beef_bones', 'beef_bouillon', 'beef_bouillon_granules', 'beef_brisket', 'beef_broth', 'beef_consomme', 'beef_drippings', 'beef_gravy', 'beef_rib_short', 'beef_roast', 'beef_shank', 'beef_sirloin', 'beef_steak', 'beef_stew_meat', 'beef_stock', 'beef_stock_cubes', 'beef_tenderloin', 'beef_tenderloin_steaks', 'beef_tongue', 'beefsteak_tomatoes', 'beer', 'beets', 'belgian_endive', 'bell_pepper', 'bengal_gram', 'berries', 'bertolli', 'bibb_lettuce', 'bicarbonate_of_soda', 'bird_chile', 'biryani_masala', 'biscuit_dough', 'biscuits', 'bisquick', 'bitters', 'bittersweet_chocolate', 'black', 'black_bean_sauce', 'black_beans', 'black_cardamom_pods', 'black_mustard_seeds', 'black_olives', 'black_pepper', 'black_peppercorns', 'black_salt', 'black_sesame_seeds', 'black_tea', 'black_tea_leaves', 'black_truffles', 'black_vinegar', 'blackberries', 'blanched_almonds', 'blood_orange', 'blue_cheese', 'blue_crabs', 'blueberries', 'bocconcini', 'boiled_egg', 'boiled_eggs', 'boiling_onions', 'boiling_potatoes', 'boiling_water', 'bok_choy', 'bone', 'bone_in_chicken_thighs', 'bone_in_skin_on_chicken_thigh', 'bone_italian_dressing', 'boneless', 'boneless_beef_chuck_roast', 'boneless_chicken', 'boneless_chicken_breast', 'boneless_chicken_breast_halves', 'boneless_chicken_skinless_thigh', 'boneless_chicken_thighs', 'boneless_chop_pork', 'boneless_chuck_roast', 'boneless_pork_loin', ...

# %%
X_train = vectorizer.transform(recipes).toarray()
Y_train = labels

# %%
from sklearn.naive_bayes import BernoulliNB
clf = BernoulliNB()
clf.fit(X_train, Y_train)
# Out:
# BernoulliNB(alpha=1.0, binarize=0.0, class_prior=None, fit_prior=True)

# %%
input_recipe = input("What is your recipe? \n> ")
while input_recipe != 'quit':
    input_recipe = input_recipe.lower()
    X_input = vectorizer.transform([input_recipe]).toarray()
    prediction = clf.predict(X_input)[0]
    
    print('\nIdentified Ingredients: \n> %s'%vectorizer.inverse_transform(X_input))
    
    print('\nPredicted Cuisine Type: \n> %s'%prediction)
    print('\n====================================')
    
    input_recipe = input("What is your recipe? \n> ")
# Out:
# What is your recipe?
# >
#
# Identified Ingredients:
# > [array([], dtype='<U39')]
#
# Predicted Cuisine Type:
# > italian
#
# ====================================
# What is your recipe?
# > quit

# %%
from sklearn.pipeline import Pipeline
NB_model = Pipeline([('vectorizer', vectorizer),('NB', clf)])
