# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
train_df = pd.read_json('../../data/train/trainText-75-25-bow.json', lines=True)

# %%
test_df = pd.read_json('../../data/test/testText-75-25-bow.json', lines=True)

# %%
train_df.head()
# Out:
#   cuisine     id                                        ingredients  label  \
# 0   greek  10259  [romaine lettuce, black olives, grape tomatoes...      0
# 1   greek  34471  [ground pork, finely chopped fresh parsley, on...      0
# 2   greek   4635  [minced garlic, dried oregano, red wine vinega...      0
# 3   greek   5980  [orange, anise, cinnamon sticks, unflavored ge...      0
# 4   greek  18031  [fresh dill, yoghurt, salt, myzithra, large eg...      0
#
#                                       numeric_recipe  \
# 0  romaine lettuce black olives grape tomatoes ga...
# 1  ground pork finely chopped fresh parsley onion...
# 2  minced garlic dried oregano red wine vinegar o...
# 3  orange anise cinnamon sticks unflavored gelati...
# 4  fresh dill yoghurt salt myzithra large eggs ch...
#
#                                               recipe
# 0  romaine lettuce black olives grape tomatoes ga...
# 1  ground pork finely chopped fresh parsley onion...
# 2  minced garlic dried oregano red wine vinegar o...
# 3  orange anise cinnamon sticks unflavored gelati...
# 4  fresh dill yoghurt salt myzithra large eggs ch...

# %%
from nltk.stem import WordNetLemmatizer 
  
lemmatizer = WordNetLemmatizer() 
  
def lemmatize(text):
    return ' '.join([lemmatizer.lemmatize(word) for word in text.split(' ')])

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer('english')
def stem(text):
    return ' '.join([stemmer.stem(word) for word in text.split(' ')])

# %%
file = open("stopwords.txt", "r")
stopwords = file.read().lower().split('\n')
def remove_stopwords(text):
    filtered = ""
    for word in text.split(' '):
        if not word in stopwords:
            filtered = filtered + ' ' + word
    return filtered

# %%
train_df['recipe'] = train_df['recipe'].apply(remove_stopwords)
train_df['recipe'] = train_df['recipe'].apply(lemmatize)

# %%
train_df.head()
# Out:
#   cuisine     id                                        ingredients  label  \
# 0   greek  10259  [romaine lettuce, black olives, grape tomatoes...      0
# 1   greek  34471  [ground pork, finely chopped fresh parsley, on...      0
# 2   greek   4635  [minced garlic, dried oregano, red wine vinega...      0
# 3   greek   5980  [orange, anise, cinnamon sticks, unflavored ge...      0
# 4   greek  18031  [fresh dill, yoghurt, salt, myzithra, large eg...      0
#
#                                       numeric_recipe  \
# 0  romaine lettuce black olives grape tomatoes ga...
# 1  ground pork finely chopped fresh parsley onion...
# 2  minced garlic dried oregano red wine vinegar o...
# 3  orange anise cinnamon sticks unflavored gelati...
# 4  fresh dill yoghurt salt myzithra large eggs ch...
#
#                                               recipe
# 0   romaine lettuce black olive grape tomato garl...
# 1           pork parsley onion salt vinegar caul fat
# 2   minced garlic dried oregano red wine vinegar ...
# 3   orange anise cinnamon stick unflavored gelati...
# 4   dill yoghurt salt myzithra egg cheese feta ch...

# %%
test_df['recipe'] = test_df['recipe'].apply(remove_stopwords)
test_df['recipe'] = test_df['recipe'].apply(lemmatize)

# %%
recipes = list(train_df['recipe'])
labels = list(train_df['cuisine'])

# %%
X_test = list(test_df['recipe'])
y_test = list(test_df['cuisine'])

# %%
vectorizer = CountVectorizer(ngram_range=(1,2), min_df=0.0005, stop_words='english', binary=True)
vectorizer.fit(recipes)
print('Number of Features: %d'%len(vectorizer.get_feature_names()))
# Out:
# Number of Features: 5675

# %%
vectorizer.get_feature_names()
# Out:
# [u'active',
#  u'active dry',
#  u'added',
#  u'adobo',
#  u'adobo sauce',
#  u'agave',
#  u'agave nectar',
#  u'aged',
#  u'ale',
#  u'alfredo',
#  u'alfredo sauce',
#  u'allspice',
#  u'allspice berry',
#  u'allspice cinnamon',
#  u'almond',
#  u'almond butter',
#  u'almond egg',
#  u'almond extract',
#  u'almond flour',
#  u'almond garlic',
#  u'almond meal',
#  u'almond milk',
#  u'almond paste',
#  u'almond salt',
#  u'amaretto',
#  u'amchur',
#  u'american',
#  u'american cheese',
#  u'amino',
#  u'anaheim',
#  u'anaheim chile',
#  u'ancho',
#  u'ancho chile',
#  u'ancho powder',
#  u'anchovy',
#  u'anchovy fillet',
#  u'anchovy paste',
#  u'andouille',
#  u'andouille sausage',
#  u'angel',
#  u'angel hair',
#  u'anise',
#  u'anise cinnamon',
#  u'anise clove',
#  u'anise seed',
#  u'apple',
#  u'apple cider',
#  u'apple juice',
#  u'applesauce',
#  u'apricot',
#  u'apricot jam',
#  u'apricot preserve',
#  u'arbol',
#  u'arborio',
#  u'arborio rice',
#  u'arrowroot',
#  u'arrowroot powder',
#  u'artichok',
#  u'artichok heart',
#  u'artichoke',
#  u'artichoke heart',
#  u'arugula',
#  u'asadero',
#  u'asafetida',
#  u'asafoetida',
#  u'asafoetida powder',
#  u'asiago',
#  u'asian',
#  u'asian fish',
#  u'asparagus',
#  u'asparagus spear',
#  u'avocado',
#  u'avocado black',
#  u'avocado cilantro',
#  u'avocado corn',
#  u'avocado garlic',
#  u'avocado green',
#  u'avocado jalapeno',
#  u'avocado lemon',
#  u'avocado lime',
#  u'avocado oil',
#  u'avocado olive',
#  u'avocado purple',
#  u'avocado red',
#  u'avocado salsa',
#  u'avocado salt',
#  u'avocado sour',
#  u'avocado tomato',
#  u'baby',
#  u'baby arugula',
#  u'baby bok',
#  u'baby carrot',
#  u'baby corn',
#  u'baby potato',
#  u'baby rib',
#  u'baby spinach',
#  u'bacon',
#  u'bacon dripping',
#  u'bacon fat',
#  u'bacon garlic',
#  u'bacon onion',
#  u'bacon slice',
#  u'bag',
#  u'baguette',
#  u'baguette extra',
#  u'baguette garlic',
#  u'baked',
#  u'baked tortilla',
#  u'ball',
#  u'balsamic',
#  u'balsamic vinaigrette',
#  u'balsamic vinegar',
#  u'balsamico',
#  u'bamboo',
#  u'bamboo shoot',
#  u'banana',
#  u'banana leaf',
#  u'banana pepper',
#  u'banana vanilla',
#  u'barbecue',
#  u'barbecue sauce',
#  u'barley',
#  u'base',
#  u'basil',
#  u'basil black',
#  u'basil butter',
#  u'basil chicken',
#  u'basil cilantro',
#  u'basil diced',
#  u'basil dried',
#  u'basil egg',
#  u'basil extra',
#  u'basil garlic',
#  u'basil grated',
#  u'basil green',
#  u'basil leaf',
#  u'basil lemon',
#  u'basil lime',
#  u'basil mint',
#  u'basil olive',
#  u'basil onion',
#  u'basil oregano',
#  u'basil parmesan',
#  u'basil parsley',
#  u'basil pepper',
#  u'basil pesto',
#  u'basil red',
#  u'basil salt',
#  u'basil sauce',
#  u'basmati',
#  u'basmati rice',
#  u'bass',
#  u'bass fillet',
#  u'bawang',
#  u'bawang goreng',
#  u'bay',
#  u'bay leaf',
#  u'bay scallop',
#  u'bay seasoning',
#  u'bbq',
#  u'bbq sauce',
#  u'bean',
#  u'bean avocado',
#  u'bean beef',
#  u'bean black',
#  u'bean carrot',
#  u'bean cheddar',
#  u'bean cheese',
#  u'bean chicken',
#  u'bean chili',
#  u'bean cilantro',
#  u'bean corn',
#  u'bean cumin',
#  u'bean curd',
#  u'bean diced',
#  u'bean dried',
#  u'bean egg',
#  u'bean extra',
#  u'bean flour',
#  u'bean frozen',
#  u'bean garlic',
#  u'bean green',
#  u'bean jalapeno',
#  u'bean lime',
#  u'bean mexican',
#  u'bean olive',
#  u'bean onion',
#  u'bean paste',
#  u'bean pepper',
#  u'bean purple',
#  u'bean red',
#  u'bean salsa',
#  u'bean salt',
#  u'bean sauce',
#  u'bean sour',
#  u'bean sprout',
#  u'bean sugar',
#  u'bean sweet',
#  u'bean taco',
#  u'bean thread',
#  u'bean tomato',
#  u'bean vegetable',
#  u'bean water',
#  u'bean white',
#  u'bean yellow',
#  u'beans',
#  u'beansprouts',
#  u'beansprouts cilantro',
#  u'beansprouts green',
#  u'beansprouts scallion',
#  u'beansprouts soy',
#  u'beaten',
#  u'beaten egg',
#  u'beef',
#  u'beef black',
#  u'beef bouillon',
#  u'beef brisket',
#  u'beef broth',
#  u'beef chuck',
#  u'beef cumin',
#  u'beef egg',
#  u'beef garlic',
#  u'beef green',
#  u'beef italian',
#  u'beef olive',
#  u'beef onion',
#  u'beef pork',
#  u'beef rib',
#  u'beef roast',
#  u'beef salt',
#  u'beef shank',
#  u'beef short',
#  u'beef sirloin',
#  u'beef stew',
#  u'beef stock',
#  u'beef taco',
#  u'beef tenderloin',
#  u'beef tomato',
#  u'beef water',
#  u'beef white',
#  u'beefsteak',
#  u'beefsteak tomato',
#  u'beer',
#  u'beet',
#  u'belgian',
#  u'belgian endive',
#  u'believe',
#  u'believe butter',
#  u'bell',
#  u'bell pepper',
#  u'belly',
#  u'berry',
#  u'bertolli',
#  u'best',
#  u'best food',
#  u'bird',
#  u'bird chile',
#  u'biscuit',
#  u'bisquick',
#  u'bitter',
#  u'bittersweet',
#  u'bittersweet chocolate',
#  u'black',
#  u'black bean',
#  u'black eyed',
#  u'black mushroom',
#  u'black mustard',
#  u'black olive',
#  u'black pepper',
#  u'black peppercorn',
#  u'black rice',
#  u'black sesame',
#  u'black tea',
#  u'black vinegar',
#  u'blackberry',
#  u'blanched',
#  u'blanched almond',
#  u'blend',
#  u'blood',
#  u'blue',
#  u'blue cheese',
#  u'blueberry',
#  u'boiled',
#  u'boiled egg',
#  u'boiling',
#  u'boiling potato',
#  u'boiling water',
#  u'bok',
#  u'bok choy',
#  u'bone',
#  u'bone chicken',
#  u'bone italian',
#  u'bone skin',
#  u'boneless',
#  u'boneless chicken',
#  u'bonito',
#  u'bonito flake',
#  u'bonnet',
#  u'bonnet chile',
#  u'boston',
#  u'boston butt',
#  u'boston lettuce',
#  u'bottled',
#  u'bottled clam',
#  u'bought',
#  u'bought chicken',
#  u'bouillon',
#  u'bouillon cube',
#  u'bouillon granule',
#  u'bourbon',
#  u'bourbon whiskey',
#  u'bow',
#  u'bow tie',
#  u'bran',
#  u'brandy',
#  u'bread',
#  u'bread black',
#  u'bread butter',
#  u'bread crumb',
#  u'bread dough',
#  u'bread egg',
#  u'bread extra',
#  u'bread flour',
#  u'bread garlic',
#  u'bread milk',
#  u'bread olive',
#  u'bread salt',
#  u'bread slice',
#  u'bread tomato',
#  u'bread unsalted',
#  u'breadcrumb',
#  u'breadcrumb egg',
#  u'breadcrumb garlic',
#  u'breadcrumb grated',
#  u'breadcrumb olive',
#  u'breadcrumb parmesan',
#  u'breadcrumb salt',
#  u'breadcrumb vegetable',
#  u'breakfast',
#  u'breakfast sausage',
#  u'breast',
#  u'breast black',
#  u'breast broccoli',
#  u'breast butter',
#  u'breast canola',
#  u'breast carrot',
#  u'breast cayenne',
#  u'breast chicken',
#  u'breast chili',
#  u'breast cilantro',
#  u'breast coconut',
#  u'breast corn',
#  u'breast cream',
#  u'breast cumin',
#  u'breast diced',
#  u'breast dried',
#  u'breast egg',
#  u'breast fillet',
#  u'breast flour',
#  u'breast garlic',
#  u'breast ginger',
#  u'breast green',
#  u'breast italian',
#  u'breast kosher',
#  u'breast lemon',
#  u'breast lime',
#  u'breast oil',
#  u'breast olive',
#  u'breast onion',
#  u'breast peanut',
#  u'breast pepper',
#  u'breast plain',
#  u'breast purple',
#  u'breast purpose',
#  u'breast red',
#  u'breast rice',
#  u'breast salsa',
#  u'breast salt',
#  u'breast scallion',
#  u'breast sesame',
#  u'breast soy',
#  u'breast taco',
#  u'breast tender',
#  u'breast tomato',
#  u'breast vegetable',
#  u'breast water',
#  u'breast white',
#  u'breast yellow',
#  u'brewed',
#  u'brewed coffee',
#  u'brie',
#  u'brie cheese',
#  u'brine',
#  u'brine cured',
#  u'brioche',
#  u'brisket',
#  u'broccoli',
#  u'broccoli floret',
#  u'broccoli rabe',
#  u'broccoli slaw',
#  u'broccolini',
#  u'broth',
#  u'broth bay',
#  u'broth black',
#  u'broth butter',
#  u'broth carrot',
#  u'broth chicken',
#  u'broth chili',
#  u'broth cilantro',
#  u'broth coconut',
#  u'broth cooking',
#  u'broth corn',
#  u'broth cumin',
#  u'broth diced',
#  u'broth dried',
#  u'broth dry',
#  u'broth egg',
#  u'broth frozen',
#  u'broth garlic',
#  u'broth ginger',
#  u'broth grated',
#  u'broth green',
#  u'broth italian',
#  u'broth lemon',
#  u'broth light',
#  u'broth lime',
#  u'broth minced',
#  u'broth olive',
#  u'broth onion',
#  u'broth peanut',
#  u'broth pepper',
#  u'broth red',
#  u'broth rice',
#  u'broth salt',
#  u'broth soy',
#  u'broth sugar',
#  u'broth thyme',
#  u'broth tomato',
#  u'broth vegetable',
#  u'broth water',
#  u'broth white',
#  u'broth yellow',
#  u'brown',
#  u'brown basmati',
#  u'brown cardamom',
#  u'brown lentil',
#  u'brown mustard',
#  u'brown rice',
#  u'brown sugar',
#  u'brussels',
#  u'brussels sprout',
#  u'buckwheat',
#  u'buffalo',
#  u'buffalo sauce',
#  u'bulb',
#  u'bulb garlic',
#  u'bulgur',
#  u'bulk',
#  u'bulk italian',
#  u'bun',
#  u'bunch',
#  u'burger',
#  u'burger bun',
#  u'butt',
#  u'butter',
#  u'butter almond',
#  u'butter apple',
#  u'butter bean',
#  u'butter beef',
#  u'butter black',
#  u'butter bread',
#  u'butter brown',
#  u'butter buttermilk',
#  u'butter carrot',
#  u'butter cayenne',
#  u'butter chicken',
#  u'butter cilantro',
#  u'butter cinnamon',
#  u'butter cocoa',
#  u'butter coconut',
#  u'butter confectioner',
#  u'butter corn',
#  u'butter cream',
#  u'butter cumin',
#  u'butter dark',
#  u'butter dried',
#  u'butter dry',
#  u'butter egg',
#  u'butter extra',
#  u'butter flat',
#  u'butter flour',
#  u'butter frozen',
#  u'butter garlic',
#  u'butter ginger',
#  u'butter granulated',
#  u'butter grated',
#  u'butter green',
#  u'butter heavy',
#  u'butter honey',
#  u'butter hot',
#  u'butter italian',
#  u'butter kosher',
#  u'butter lemon',
#  u'butter lettuce',
#  u'butter light',
#  u'butter lime',
#  u'butter maple',
#  u'butter milk',
#  u'butter minced',
#  u'butter mushroom',
#  u'butter oil',
#  u'butter olive',
#  u'butter onion',
#  u'butter orange',
#  u'butter panko',
#  u'butter parsley',
#  u'butter pecan',
#  u'butter pepper',
#  u'butter plain',
#  u'butter powder',
#  u'butter powdered',
#  u'butter purpose',
#  u'butter red',
#  u'butter rice',
#  u'butter salt',
#  u'butter shallot',
#  u'butter shrimp',
#  u'butter sour',
#  u'butter soy',
#  u'butter spread',
#  u'butter sugar',
#  u'butter sweet',
#  u'butter thyme',
#  u'butter tomato',
#  u'butter vanilla',
#  u'butter vegetable',
#  u'butter water',
#  u'butter white',
#  u'butter yellow',
#  u'buttermilk',
#  u'buttermilk biscuit',
#  u'buttermilk egg',
#  u'buttermilk purpose',
#  u'butternut',
#  u'butternut squash',
#  u'button',
#  u'button mushroom',
#  u'cabbage',
#  u'cabbage carrot',
#  u'cabbage chicken',
#  u'cabbage cilantro',
#  u'cabbage garlic',
#  u'cabbage green',
#  u'cabbage leaf',
#  u'cabbage onion',
#  u'cabbage red',
#  u'cabbage salt',
#  u'cabbage scallion',
#  u'cabbage soy',
#  u'cabbage water',
#  u'cachaca',
#  u'cage',
#  u'cage free',
#  u'cajun',
#  u'cajun seasoning',
#  u'cake',
#  u'cake flour',
#  u'cake mix',
#  u'calamari',
#  u'california',
#  u'california bay',
#  u'campbell',
#  u'campbell condensed',
#  u'candied',
#  u'candy',
#  u'cane',
#  u'cane sugar',
#  u'canned',
#  u'canned black',
#  u'canned chicken',
#  u'canned corn',
#  u'canned tomato',
#  u'cannellini',
#  u'cannellini bean',
#  u'canola',
#  u'canola oil',
#  u'cantaloupe',
#  u'cap',
#  u'caper',
#  u'caper olive',
#  u'capsicum',
#  u'caramel',
#  u'caramel sauce',
#  u'caraway',
#  u'caraway seed',
#  u'carbonated',
#  u'carbonated water',
#  u'cardamom',
#  u'cardamom cinnamon',
#  u'cardamom clove',
#  u'cardamom cumin',
#  u'cardamom onion',
#  u'cardamom pod',
#  u'cardamom seed',
#  u'cardamon',
#  u'carrot',
#  u'carrot beansprouts',
#  u'carrot black',
#  u'carrot broccoli',
#  u'carrot cabbage',
#  u'carrot celery',
#  u'carrot chicken',
#  u'carrot cilantro',
#  u'carrot cucumber',
#  u'carrot cumin',
#  u'carrot dried',
#  u'carrot egg',
#  u'carrot frozen',
#  u'carrot garlic',
#  u'carrot ginger',
#  u'carrot green',
#  u'carrot lime',
#  u'carrot olive',
#  u'carrot onion',
#  u'carrot peanut',
#  u'carrot pepper',
#  u'carrot potato',
#  u'carrot red',
#  u'carrot rice',
#  u'carrot salt',
#  u'carrot scallion',
#  u'carrot snow',
#  u'carrot soy',
#  u'carrot sugar',
#  u'carrot tomato',
#  u'carrot vegetable',
#  u'carrot water',
#  u'carrot white',
#  u'carrot zucchini',
#  u'cashew',
#  u'cashew nut',
#  u'casing',
#  u'cassia',
#  u'caster',
#  u'caster sugar',
#  u'catfish',
#  u'catfish fillet',
#  u'cauliflower',
#  u'cauliflower floret',
#  u'cayenne',
#  u'cayenne garlic',
#  u'cayenne pepper',
#  u'cayenne salt',
#  u'celery',
#  u'celery carrot',
#  u'celery chicken',
#  u'celery garlic',
#  u'celery green',
#  u'celery onion',
#  u'celery red',
#  u'celery rib',
#  u'celery root',
#  u'celery salt',
#  u'celery seed',
#  u'celery tomato',
#  u'center',
#  u'center cut',
#  u'cereal',
#  u'chaat',
#  u'chaat masala',
#  u'challa',
#  u'champagne',
#  u'champagne vinegar',
#  u'chana',
#  u'chana dal',
#  u'char',
#  u'char siu',
#  u'chard',
#  u'chayotes',
#  u'cheddar',
#  u'cheddar cheese',
#  u'chees',
#  u'chees mozzarella',
#  u'cheese',
#  u'cheese avocado',
#  u'cheese baby',
#  u'cheese bacon',
#  u'cheese balsamic',
#  u'cheese basil',
#  u'cheese beef',
#  u'cheese black',
#  u'cheese blend',
#  u'cheese bread',
#  u'cheese butter',
#  u'cheese carrot',
#  u'cheese cheddar',
#  u'cheese cheese',
#  u'cheese chicken',
#  u'cheese chili',
#  u'cheese chive',
#  u'cheese cilantro',
#  u'cheese cooking',
#  u'cheese corn',
#  u'cheese cream',
#  u'cheese crumbles',
#  u'cheese cumin',
#  u'cheese cup',
#  u'cheese diced',
#  u'cheese dried',
#  u'cheese dry',
#  u'cheese egg',
#  u'cheese extra',
#  u'cheese fat',
#  u'cheese feta',
#  u'cheese flat',
#  u'cheese flour',
#  u'cheese french',
#  u'cheese frozen',
#  u'cheese garlic',
#  u'cheese grated',
#  u'cheese greek',
#  u'cheese green',
#  u'cheese heavy',
#  u'cheese hot',
#  u'cheese italian',
#  u'cheese jalapeno',
#  u'cheese kalamata',
#  u'cheese kosher',
#  u'cheese lasagna',
#  u'cheese lemon',
#  u'cheese lettuce',
#  u'cheese lime',
#  u'cheese low',
#  u'cheese marinara',
#  u'cheese mayonnaise',
#  u'cheese milk',
#  u'cheese minced',
#  u'cheese monterey',
#  u'cheese mozzarella',
#  u'cheese mushroom',
#  u'cheese oil',
#  u'cheese olive',
#  u'cheese onion',
#  u'cheese oregano',
#  u'cheese panko',
#  u'cheese parmesan',
#  u'cheese parsley',
#  u'cheese pasta',
#  u'cheese penne',
#  u'cheese pepper',
#  u'cheese pepperoni',
#  u'cheese pinenuts',
#  u'cheese pizza',
#  u'cheese plain',
#  u'cheese plum',
#  u'cheese powdered',
#  u'cheese purple',
#  u'cheese purpose',
#  u'cheese ravioli',
#  u'cheese red',
#  u'cheese ricotta',
#  u'cheese roasted',
#  u'cheese salsa',
#  u'cheese salt',
#  u'cheese sauce',
#  u'cheese scallion',
#  u'cheese sea',
#  u'cheese sharp',
#  u'cheese skim',
#  u'cheese slice',
#  u'cheese soften',
#  u'cheese sour',
#  u'cheese spaghetti',
#  u'cheese spinach',
#  u'cheese sugar',
#  u'cheese sweet',
#  u'cheese taco',
#  u'cheese thyme',
#  u'cheese tomato',
#  u'cheese tortellini',
#  u'cheese tortilla',
#  u'cheese unsalted',
#  u'cheese vegetable',
#  u'cheese water',
#  u'cheese wheat',
#  u'cheese white',
#  u'cheese yellow',
#  u'cheese zucchini',
#  u'cherry',
#  u'cherry tomato',
#  u'chervil',
#  u'chestnut',
#  u'chestnut green',
#  u'chia',
#  u'chia seed',
#  u'chicken',
#  u'chicken black',
#  u'chicken bouillon',
#  u'chicken breast',
#  u'chicken broth',
#  u'chicken chicken',
#  u'chicken cilantro',
#  u'chicken corn',
#  u'chicken cutlet',
#  u'chicken drumstick',
#  u'chicken egg',
#  u'chicken fillet',
#  u'chicken finger',
#  u'chicken flavor',
#  u'chicken flavored',
#  u'chicken garlic',
#  u'chicken ginger',
#  u'chicken green',
#  u'chicken leg',
#  u'chicken liver',
#  u'chicken meat',
#  u'chicken olive',
#  u'chicken onion',
#  u'chicken pepper',
#  u'chicken piece',
#  u'chicken red',
#  u'chicken salt',
#  u'chicken sausage',
#  u'chicken soup',
#  u'chicken soy',
#  u'chicken stock',
#  u'chicken tenderloin',
#  u'chicken thigh',
#  u'chicken tomato',
#  u'chicken vegetable',
#  u'chicken water',
#  u'chicken wing',
#  u'chickpea',
#  u'chickpea flour',
#  u'chickpea onion',
#  u'chile',
#  u'chile arbol',
#  u'chile black',
#  u'chile chicken',
#  u'chile cilantro',
#  u'chile cumin',
#  u'chile garlic',
#  u'chile ginger',
#  u'chile green',
#  u'chile kosher',
#  u'chile lime',
#  u'chile olive',
#  u'chile onion',
#  u'chile paste',
#  u'chile pepper',
#  u'chile powder',
#  u'chile salt',
#  u'chile sauce',
#  u'chile sugar',
#  u'chile tomato',
#  u'chile vegetable',
#  u'chile water',
#  u'chile white',
#  u'chili',
#  u'chili bean',
#  u'chili flake',
#  u'chili garlic',
#  u'chili oil',
#  u'chili paste',
#  u'chili pepper',
#  u'chili powder',
#  u'chili sauce',
#  u'chilies',
#  u'chilies avocado',
#  u'chilies black',
#  u'chilies chicken',
#  u'chilies chili',
#  u'chilies cilantro',
#  u'chilies coriander',
#  u'chilies corn',
#  u'chilies cumin',
#  u'chilies curry',
#  u'chilies diced',
#  u'chilies garlic',
#  u'chilies ginger',
#  u'chilies green',
#  u'chilies lemon',
#  u'chilies lime',
#  u'chilies olive',
#  u'chilies onion',
#  u'chilies purple',
#  u'chilies red',
#  u'chilies salt',
#  u'chilies sour',
#  u'chilies tomato',
#  u'chilies turmeric',
#  u'chilies vegetable',
#  u'chilies white',
#  u'chilli',
#  u'chilli paste',
#  u'chinese',
#  u'chinese black',
#  u'chinese cabbage',
#  u'chinese chive',
#  u'chinese egg',
#  u'chinese eggplant',
#  u'chinese noodle',
#  u'chinese rice',
#  u'chinese sausage',
#  u'chinese spice',
#  u'chinkiang',
#  u'chinkiang vinegar',
#  u'chip',
#  u'chip cilantro',
#  u'chipotle',
#  u'chipotle adobo',
#  u'chipotle chile',
#  u'chipotle pepper',
#  u'chive',
#  u'chive garlic',
#  u'chive salt',
#  u'chocolate',
#  u'chocolate chip',
#  u'chocolate egg',
#  u'chocolate heavy',
#  u'chocolate milk',
#  u'chocolate morsel',
#  u'chocolate unsalted',
#  u'chocolate vanilla',
#  u'chop',
#  u'chorizo',
#  u'chorizo onion',
#  u'chorizo sausage',
#  u'chow',
#  u'chow mein',
#  u'choy',
#  u'choy sum',
#  u'chuck',
#  u'chuck roast',
#  u'chunk',
#  u'chunky',
#  u'chunky peanut',
#  u'chunky salsa',
#  u'chutney',
#  u'ciabatta',
#  u'cider',
#  u'cider vinegar',
#  u'cilantro',
#  u'cilantro avocado',
#  u'cilantro basil',
#  u'cilantro black',
#  u'cilantro brown',
#  u'cilantro cayenne',
#  u'cilantro chicken',
#  u'cilantro chile',
#  u'cilantro chili',
#  u'cilantro coconut',
#  u'cilantro corn',
#  u'cilantro cumin',
#  u'cilantro diced',
#  u'cilantro egg',
#  u'cilantro fish',
#  u'cilantro flour',
#  u'cilantro garlic',
#  u'cilantro ginger',
#  u'cilantro green',
#  u'cilantro jalapeno',
#  u'cilantro kosher',
#  u'cilantro leaf',
#  u'cilantro lemon',
#  u'cilantro lime',
#  u'cilantro minced',
#  u'cilantro mint',
#  u'cilantro oil',
#  u'cilantro olive',
#  u'cilantro onion',
#  u'cilantro peanut',
#  u'cilantro pepper',
#  u'cilantro purple',
#  u'cilantro red',
#  u'cilantro rice',
#  u'cilantro root',
#  u'cilantro salsa',
#  u'cilantro salt',
#  u'cilantro scallion',
#  u'cilantro sour',
#  u'cilantro soy',
#  u'cilantro sprig',
#  u'cilantro stem',
#  u'cilantro sugar',
#  u'cilantro sweet',
#  u'cilantro tomato',
#  u'cilantro tortilla',
#  u'cilantro vegetable',
#  u'cilantro water',
#  u'cilantro white',
#  u'cilantro yellow',
#  u'cinnamon',
#  u'cinnamon black',
#  u'cinnamon butter',
#  u'cinnamon cardamom',
#  u'cinnamon cayenne',
#  u'cinnamon clove',
#  u'cinnamon cumin',
#  u'cinnamon egg',
#  ...]

# %%
#import pickle
#filename = 'vectorizer.sav'
#pickle.dump(vectorizer, open(filename,'wb'))

# %%
X_train = vectorizer.transform(recipes).toarray()
y_train = labels

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
from sklearn.pipeline import Pipeline
DecTree_model = Pipeline([('vectorizer', vectorizer),('LR', clf)])

# %%
from sklearn import metrics
y_pred = DecTree_model.predict(X_test)
print(metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#    brazilian       0.55      0.45      0.50       117
#      british       0.31      0.22      0.26       201
# cajun_creole       0.59      0.50      0.54       387
#      chinese       0.87      1.00      0.93      3294
#     filipino       0.49      0.34      0.40       189
#       french       0.65      0.59      0.62      2205
#        greek       0.82      0.79      0.81      1544
#       indian       0.87      0.89      0.88      2119
#        irish       0.37      0.31      0.34       167
#      italian       0.60      0.90      0.72      4310
#     jamaican       0.58      0.36      0.44       132
#     japanese       0.82      0.71      0.76      1557
#       korean       0.61      0.38      0.47       208
#      mexican       0.79      0.53      0.63      3600
#     moroccan       0.52      0.39      0.45       206
#      russian       0.24      0.16      0.20       123
#  southern_us       0.58      0.53      0.55      1080
#      spanish       0.66      0.61      0.63      1251
#         thai       0.76      0.64      0.70      1706
#   vietnamese       0.43      0.35      0.39       207
#
#    micro avg       0.72      0.72      0.72     24603
#    macro avg       0.61      0.53      0.56     24603
# weighted avg       0.72      0.72      0.71     24603

# %%
input_recipe = input("Input Recipe: \n> ")
input_recipe = stem(input_recipe.lower())
X_input = vectorizer.transform([input_recipe]).toarray()
pred = clf.predict(X_input)
classes = clf.classes_

print('\nIdentified Ingredients: \n> %s'%vectorizer.inverse_transform(X_input))

print('\nCuisine Prediction: %s'%pred)

# %%
import pickle
filename = 'DecTreeV1.sav'
pickle.dump(DecTree_model, open(filename,'wb'))
