# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
df = pd.read_json('../../data/train/trainText-75-25.json', lines=True)

# %%
ingredients = {}
for lst in df['ingredientsFiltered']:
    for i in lst:
        i = i.replace(' ','_').strip('_')
        if not i in ingredients:
            ingredients[i] = 1
        else:
            ingredients[i] += 1

# %%
ingredients['black_olives']
# Out:
# 774

# %%
MIN_FREQUENCY = 10
filtered_ingredients = {k: v for k, v in ingredients.items() if v >= MIN_FREQUENCY}

# %%
recipes = list(df['recipe'])
labels = list(df['cuisine'])

# %%
vectorizer = CountVectorizer()
vectorizer.fit(filtered_ingredients.keys())
print('Number of Features: %d'%len(vectorizer.get_feature_names()))
# Out:
# Number of Features: 3092

# %%
print(vectorizer.get_feature_names())
# Out:
# ['____oz', '_alfredo_sauce', '_asiago', '_beaten', '_best_food_mayonnais', '_best_food_real_mayonnais', '_butter', '_capicola', '_chicken_breast', '_chicken_broth', '_chicken_tenderloins', '_chinese_black_vinegar_dark_soy_sauce_chicken_stock_peanut_oil_red_onion', '_chop', '_chunky_mild_salsa', '_classic_hummus', '_classico_olive_oil', '_cook_drain', '_cookies', '_crush', '_crushed_finely_grated_ginger_½_sichuan_peppercorns', '_crushed_long_dried_red_chillies', '_dash', '_diced', '_diced_tomatoes', '_drain', '_eggs', '_fiesta_sides_spanish_rice', '_finely', '_garlic_cloves', '_genoa_salami', '_green_chiles', '_half', '_half_lengthways', '_halved_thinly_lengthways_', '_italian_loaf', '_less', '_lightly_beaten', '_manchego', '_meats_fish', '_natural_sweetener', '_parmigiano', '_peel_devein', '_pie_filling', '_prosciutto', '_real_mayonnaise', '_refried_beans', '_refrigerated_crescent_dinner_rolls', '_rins_drain', '_salmon', '_sharp_cheddar', '_shrimp', '_slice', '_soften', '_soppressata', '_spread', '_taco_seasoning_mix', '_taste', '_thawed_squeezed_dry', '_thick_', '_thin_strips_¼_five', '_tomato_sauce', '_water', '_wedges_of_cheese', '_well_scrub', '_well_scrubbed', '_yams', 'abura_age', 'achiote', 'achiote_paste', 'acorn_squash', 'acting_baking_powder', 'active_dry_yeast', 'added_black_beans', 'added_diced_tomatoes', 'adobo', 'adobo_sauce', 'adobo_seasoning', 'agar', 'agave_nectar', 'aged_balsamic_vinegar', 'ahi', 'aioli', 'ajwain', 'albacore', 'albacore_tuna_water', 'ale', 'aleppo_pepper', 'alfalfa_sprouts', 'alfredo_sauce', 'all', 'all_purpose_unbleached_flour', 'allspice', 'allspice_berries', 'almond_butter', 'almond_extract', 'almond_flour', 'almond_meal', 'almond_milk', 'almond_paste', 'almonds', 'amaretti_cookies', 'amaretto', 'amaretto_liqueur', 'amchur', 'american_cheese', 'anaheim_chile', 'ancho', 'ancho_chile_pepper', 'ancho_chili_pepper', 'ancho_powder', 'anchovies', 'anchovy_fillets', 'anchovy_paste', 'andouille_sausage', 'andouille_sausage_links', 'angel_hair', 'angostura_bitters', 'anise', 'anise_extract', 'anise_seed', 'annatto_seeds', 'apple_butter', 'apple_cider', 'apple_cider_vinegar', 'apple_jelly', 'apple_juice', 'apple_pie_filling', 'apples', 'applesauce', 'applewood_bacon', 'apricot_halves', 'apricot_jam', 'apricot_preserves', 'apricots', 'arbol_chile', 'arborio_rice', 'armagnac', 'arrowroot', 'arrowroot_powder', 'arrowroot_starch', 'artichok_heart_marin', 'artichoke_hearts', 'artichokes', 'artisan_bread', 'arugula', 'asadero', 'asafetida', 'asafoetida', 'asafoetida_powder', 'asiago', 'asian_chili_sauce', 'asian_eggplants', 'asian_fish_sauce', 'asian_pear', 'asian_sesame_oil', 'asian_sweet_chili_sauce', 'asparagus', 'asparagus_spears', 'assorted_vegetables', 'atar', 'atta', 'avocado', 'avocado_oil', 'avocado_slices', 'açai', 'baby_arugula', 'baby_back_ribs', 'baby_bok_choy', 'baby_carrots', 'baby_corn', 'baby_eggplants', 'baby_greens', 'baby_kale', 'baby_lima_beans', 'baby_portobello_mushrooms', 'baby_potatoes', 'baby_spinach', 'baby_spinach_leaves', 'baby_zucchini', 'back_bacon_rashers', 'bacon', 'bacon_bits', 'bacon_drippings', 'bacon_fat', 'bacon_grease', 'bacon_pieces', 'bacon_slices', 'baguette', 'baileys_irish_cream_liqueur', 'baked_beans', 'baked_ham', 'baked_pizza_crust', 'baked_tortilla_chips', 'baking_mix', 'baking_potatoes', 'baking_powder', 'baking_soda', 'baking_spray', 'balsamic_reduction', 'balsamic_vinaigrette', 'balsamic_vinaigrette_salad_dressing', 'balsamic_vinegar', 'balsamico_bianco', 'bamboo_shoots', 'banana_leaves', 'banana_peppers', 'bananas', 'barbecue_sauce', 'barbecued_pork', 'barley', 'bartlett_pears', 'base', 'basil', 'basil_dried_leaves', 'basil_leaves', 'basil_pesto', 'basil_pesto_sauce', 'basmati', 'basmati_rice', 'baton', 'bawang_goreng', 'bay_leaf', 'bay_leaves', 'bay_scallops', 'bbq_sauce', 'bean_curd', 'bean_curd_skins', 'bean_dip', 'bean_paste', 'bean_sauce', 'bean_sprouts', 'bean_threads', 'beans', 'beansprouts', 'beaten_eggs', 'bechamel', 'beef', 'beef_base', 'beef_b ...

# %%
X_train = vectorizer.transform(recipes).toarray()
Y_train = labels

# %%
from sklearn.naive_bayes import BernoulliNB
clf = BernoulliNB()
clf.fit(X_train, Y_train)
# Out:
# BernoulliNB(alpha=1.0, binarize=0.0, class_prior=None, fit_prior=True)

# %%
input_recipe = input("What is your recipe? \n> ")
while input_recipe != 'quit':
    input_recipe = input_recipe.lower()
    X_input = vectorizer.transform([input_recipe]).toarray()
    prediction = clf.predict(X_input)[0]
    
    print('\nIdentified Ingredients: \n> %s'%vectorizer.inverse_transform(X_input))
    
    print('\nPredicted Cuisine Type: \n> %s'%prediction)
    print('\n====================================')
    
    input_recipe = input("What is your recipe? \n> ")
# Out:
# What is your recipe?
# > salmon
#
# Identified Ingredients:
# > [array(['salmon'], dtype='<U72')]
#
# Predicted Cuisine Type:
# > japanese
#
# ====================================
# What is your recipe?
# > quit

# %%
from sklearn.pipeline import Pipeline
NB_model = Pipeline([('vectorizer', vectorizer),('NB', clf)])

# %%
import pickle
filename = 'NB_model_v2.sav'
pickle.dump(NB_model, open(filename,'wb'))

# %%
NB_model.predict(list(['hi', 'hi']))
# Out:
# array(['italian', 'italian'], dtype='<U12')
