# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
df = pd.read_json('../../data/train/trainText-75-25.json', lines=True)

# %%
df.head()
# Out:
#   cuisine     id                                        ingredients  \
# 0   greek  10259  [romaine lettuce, black olives, grape tomatoes...
# 1   greek  34471  [ground pork, finely chopped fresh parsley, on...
# 2   greek   4635  [minced garlic, dried oregano, red wine vinega...
# 3   greek   5980  [orange, anise, cinnamon sticks, unflavored ge...
# 4   greek  18031  [fresh dill, yoghurt, salt, myzithra, large eg...
#
#                                  ingredientsFiltered  label  \
# 0  [romaine lettuce, black olives, grape tomatoes...      0
# 1  [pork, finely parsley, onions, salt, vinegar, ...      0
# 2  [garlic, dried oregano, red wine vinegar, oliv...      0
# 3  [orange, anise, cinnamon sticks, unflavored ge...      0
# 4  [dill, yoghurt, salt, myzithra, eggs, cheese, ...      0
#
#                                               recipe
# 0  romaine lettuce black_olives grape_tomatoes ga...
# 1   pork finely_parsley onions salt vinegar caul_fat
# 2  garlic dried_oregano red_wine_vinegar olive_oi...
# 3  orange anise cinnamon_sticks unflavored_gelati...
# 4  dill yoghurt salt myzithra eggs cheese feta_ch...

# %%
ingredients = {}
for lst in df['ingredientsFiltered']:
    for i in lst:
        if not i in ingredients:
            ingredients[i] = 1
        else:
            ingredients[i] += 1

# %%
ingredients
# Out:
# {'romaine lettuce': 632,
#  'black olives': 774,
#  'grape tomatoes': 534,
#  'garlic': 30346,
#  'pepper': 10716,
#  'purple onion': 3949,
#  'seasoning': 324,
#  'garbanzo beans': 247,
#  'feta cheese crumbles': 876,
#  'pork': 1701,
#  'finely parsley': 124,
#  'onions': 13066,
#  'salt': 31247,
#  'vinegar': 542,
#  'caul fat': 3,
#  'dried oregano': 2913,
#  'red wine vinegar': 1454,
#  'olive oil': 13869,
#  'boneless chop pork': 34,
#  'lemon juice': 5069,
#  'orange': 647,
#  'anise': 82,
#  'cinnamon sticks': 1034,
#  'unflavored gelatin': 114,
#  'zinfandel': 10,
#  'orange blossom honey': 12,
#  'sugar': 13120,
#  'lemon': 2628,
#  'calimyrna figs': 14,
#  '': 1682,
#  'honey': 3267,
#  'whipping cream': 717,
#  'plain whole-milk yogurt': 78,
#  'dill': 760,
#  'yoghurt': 636,
#  'myzithra': 4,
#  'eggs': 12407,
#  'cheese': 1372,
#  'feta cheese': 879,
#  'phyllo': 27,
#  'kefalotyri': 14,
#  'black pepper': 11926,
#  'extra-virgin olive oil': 5009,
#  'hamburger buns': 126,
#  'paprika': 3104,
#  'mint': 1516,
#  'cinnamon': 3520,
#  'balsamic vinegar': 981,
#  'baby spinach leaves': 207,
#  'lamb': 351,
#  'dried mint flakes': 29,
#  'tomatoes': 6474,
#  'dried dillweed': 60,
#  'red wine': 429,
#  'plain yogurt': 698,
#  'pita bread rounds': 30,
#  'cucumber': 2150,
#  'liquid': 102,
#  'tahini': 178,
#  'dry red wine': 376,
#  'Turkish bay leaves': 21,
#  'oregano': 1782,
#  'octopuses': 16,
#  'mint leaves': 499,
#  'almonds': 972,
#  'vanilla lowfat yogurt': 6,
#  'kosher salt': 5967,
#  'greek yogurt': 1351,
#  'cracked black pepper': 775,
#  'english cucumber': 491,
#  'shallots': 2801,
#  'white vinegar': 885,
#  'water': 12689,
#  'dried currants': 88,
#  'swiss chard': 143,
#  'eggplant': 794,
#  'grated parmesan cheese': 2938,
#  'plain breadcrumbs': 49,
#  'egg yolks': 1633,
#  'diced tomatoes': 2653,
#  'all-purpose flour': 6053,
#  'bay leaf': 1294,
#  'tomato paste': 1946,
#  'unsalted butter': 3882,
#  'allspice': 531,
#  'milk': 4207,
#  'grated nutmeg': 290,
#  'juice': 435,
#  'green pepper': 763,
#  'capers': 728,
#  'vinaigrette dressing': 17,
#  'kalamata': 511,
#  'parsley': 3630,
#  'rosemary': 857,
#  'thyme leaves': 360,
#  'yellow bell pepper': 508,
#  'fat skimmed chicken broth': 79,
#  'couscous': 187,
#  'greek seasoning': 129,
#  'brown rice': 586,
#  'chicken stock': 2224,
#  'red bell pepper': 3663,
#  'whole milk': 1162,
#  'bread crumb': 155,
#  'parmigiano reggiano cheese': 481,
#  'thyme sprigs': 252,
#  'ziti': 40,
#  'heavy cream': 1973,
#  'puff pastry': 103,
#  'flour for dusting': 44,
#  'dry white wine': 1561,
#  'leaf parsley': 20,
#  'mussels': 307,
#  'Greek feta': 19,
#  'chicken thighs': 781,
#  'sweet paprika': 251,
#  'bay leaves': 1419,
#  'pitted prunes': 30,
#  'cherry tomatoes': 1129,
#  'sea salt': 2932,
#  'white wine vinegar': 600,
#  'quinoa': 572,
#  'italian seasoning': 1258,
#  'baby spinach': 597,
#  'crushed red pepper': 1162,
#  'walnuts': 462,
#  'vanilla': 1013,
#  'kale': 383,
#  'rosemary sprigs': 124,
#  'fat less sodium chicken broth': 479,
#  'white bread': 254,
#  'pitted kalamata olives': 338,
#  'cooking spray': 1708,
#  'boneless chicken breast halves': 966,
#  'cayenne pepper': 2559,
#  'warm water': 1002,
#  'chickpeas': 852,
#  'tahini paste': 13,
#  'coarse salt': 889,
#  'boiling water': 481,
#  'pinenuts': 465,
#  'roasted red peppers': 488,
#  'red pepper flakes': 1629,
#  'yellow onion': 2356,
#  'beef': 3070,
#  'dill weed': 51,
#  'nutmeg': 1257,
#  'sour cream': 2718,
#  'grated lemon zest': 420,
#  'unsalted chicken stock': 28,
#  'crushed tomatoes': 739,
#  'oven-ready lasagna noodles': 54,
#  'onion': 1830,
#  'part-skim ricotta cheese': 149,
#  'flat leaf parsley': 1797,
#  'oregano leaves': 144,
#  'boneless chicken breasts': 2674,
#  'marinade': 220,
#  'oil': 4707,
#  'chicken': 2802,
#  'plain low-fat yogurt': 53,
#  'baking potatoes': 247,
#  'low-fat milk': 312,
#  'sharp cheddar cheese': 550,
#  'aleppo pepper': 26,
#  'green bell pepper': 1937,
#  'turkey': 660,
#  'garlic powder': 3011,
#  'cumin': 6982,
#  'yellow mustard': 76,
#  'tomato sauce': 1467,
#  'dried basil': 969,
#  'crushed red pepper flakes': 980,
#  'lamb shoulder': 110,
#  'tomatoes with juice': 120,
#  'bulgur': 28,
#  'frozen spinach': 396,
#  'part-skim mozzarella cheese': 285,
#  'fat milk': 156,
#  'baking powder': 2355,
#  'vine tomatoes': 26,
#  'leg of lamb': 108,
#  'egg substitute': 88,
#  'corn starch': 4688,
#  'bulgur wheat': 13,
#  'parmesan cheese': 1755,
#  'chicken breasts': 2288,
#  'nonfat greek yogurt': 144,
#  'fat yogurt': 85,
#  'dried rosemary': 266,
#  'cottage cheese': 144,
#  'butter': 7823,
#  'phyllo dough': 94,
#  'oz.) frozen spinach, thawed squeezed dry': 2,
#  'tzatziki': 16,
#  'pita bread': 107,
#  'greek plain yogurt': 115,
#  'boneless lamb': 10,
#  'button mushrooms': 277,
#  'vegetable stock': 439,
#  'brown lentils': 61,
#  'zucchini': 1796,
#  'herbes de provence': 90,
#  'goat cheese': 251,
#  'dijon mustard': 988,
#  'frisee': 25,
#  'red pepper': 1706,
#  'broccoli florets': 522,
#  'Wish-Bone Italian Dressing': 56,
#  'vanilla extract': 2293,
#  'almond extract': 291,
#  'confectioners sugar': 640,
#  'white sugar': 1647,
#  'iceberg lettuce': 311,
#  'beefsteak tomatoes': 47,
#  'rice': 2026,
#  'chicken broth': 2732,
#  'whole chicken': 91,
#  'orzo pasta': 78,
#  'russet potatoes': 450,
#  'coarse kosher salt': 80,
#  'beef broth': 640,
#  'brown sugar': 4134,
#  'pumpkin purée': 104,
#  'baking soda': 1271,
#  'whole wheat flour': 301,
#  'pecans': 522,
#  'bananas': 559,
#  'ginger': 11264,
#  'vegetable broth': 867,
#  'basmati rice': 596,
#  'bison': 10,
#  'cayenne': 779,
#  'green beans': 746,
#  'hearts of palm': 21,
#  'greek-style vinaigrette': 24,
#  'artichoke hearts': 256,
#  'kalamata olives': 35,
#  'flatbread': 77,
#  'lemon wedge': 208,
#  'spinach': 1129,
#  'sun-dried tomatoes': 320,
#  'white rice': 806,
#  'mushrooms': 1833,
#  'ripe olives': 124,
#  'sub buns': 17,
#  'Balsamico Bianco': 24,
#  'lettuce leaves': 302,
#  'ham': 498,
#  'turkey breast': 122,
#  'branzino': 7,
#  'mini phyllo dough shells': 9,
#  'cheddar cheese': 1959,
#  'mayonaise': 667,
#  'pimentos': 172,
#  'active dry yeast': 658,
#  'pastry flour': 8,
#  'applesauce': 28,
#  'dry yeast': 163,
#  'chuck roast': 127,
#  'cooking wine': 186,
#  'liquid smoke': 74,
#  'bell pepper': 935,
#  'whole milk greek yogurt': 39,
#  'pitas': 100,
#  'flank steak': 483,
#  'arugula': 289,
#  'parsley leaves': 298,
#  'plum tomatoes': 1151,
#  'whole wheat pita': 29,
#  'pecorino romano cheese': 223,
#  'lemon zest': 523,
#  'curly leaf spinach': 3,
#  'scallions': 4305,
#  'plain flour': 297,
#  'vegetable oil': 7556,
#  'caster sugar': 306,
#  'egg whites': 1778,
#  'tarama': 2,
#  'french bread': 669,
#  'safflower oil': 75,
#  'green onions': 7151,
#  'pork loin chops': 83,
#  'diced red onions': 173,
#  'coffee': 120,
#  'basil': 2433,
#  'edamame': 157,
#  'chili pepper flakes': 35,
#  'celery': 1704,
#  'clams': 141,
#  'salad dressing': 125,
#  'peas': 410,
#  'semolina': 85,
#  'whole': 100,
#  'olives': 393,
#  'beau monde seasoning': 4,
#  'low-fat cottage cheese': 47,
#  'onion powder': 1084,
#  'yellow crookneck squash': 9,
#  'thyme': 1549,
#  'vegetable oil spray': 93,
#  'mint sprigs': 135,
#  'roasting chickens': 94,
#  'pita rounds': 12,
#  'kirby cucumbers': 35,
#  'naan': 96,
#  'boneless chicken thighs': 680,
#  'anchovy paste': 88,
#  'red potato': 398,
#  'dried thyme': 1064,
#  'baby lima beans': 33,
#  'sweet onion': 621,
#  'orzo': 144,
#  'bread crumbs': 691,
#  'grated carrot': 87,
#  'luke warm water': 62,
#  'strong white bread flour': 31,
#  'radishes': 463,
#  'whole wheat pita bread': 9,
#  'dried parsley': 368,
#  'bouillon granules': 3,
#  'cauliflower': 593,
#  'rigatoni': 114,
#  'salt black pepper': 301,
#  'lettuce': 750,
#  'dillweed': 4,
#  'diced bell pepper': 18,
#  'non-fat sour cream': 163,
#  'penne pasta': 263,
#  'cream cheese, soften': 132,
#  'bread': 636,
#  'artichok heart marin': 51,
#  'low salt chicken broth': 390,
#  'chicken breast halves': 189,
#  'grated lemon peel': 192,
#  'cream cheese': 1158,
#  'chicken pieces': 161,
#  'plums': 117,
#  'hazelnuts': 146,
#  'bone chicken thighs': 81,
#  'caesar salad dressing': 23,
#  'pitted black olives': 92,
#  'red leaf lettuce': 30,
#  'lamb shanks': 53,
#  'marsala wine': 155,
#  'golden raisins': 265,
#  'raita': 18,
#  'pasta': 624,
#  'grated kefalotiri': 3,
#  'nonfat plain greek yogurt': 163,
#  'coleslaw': 36,
#  'cider vinegar': 399,
#  'long grain white rice': 435,
#  'liver': 20,
#  'green bean': 82,
#  'boneless chicken thigh': 323,
#  'lemon pepper seasoning': 20,
#  'finely onion': 580,
#  'poultry seasoning': 63,
#  'canola oil': 2359,
#  'diced onions': 390,
#  'leav spinach': 56,
#  'sumac': 30,
#  'orange bell pepper': 224,
#  'spring onions': 1070,
#  'low-fat greek yogurt': 49,
#  'chives': 909,
#  'savory': 24,
#  'pancetta': 244,
#  'fava bean': 15,
#  'fennel seeds': 653,
#  'fennel bulb': 254,
#  'pita loaves': 5,
#  'basil leaves': 1364,
#  'plain low fat greek yogurt': 35,
#  'curry powder': 1268,
#  'red grape': 12,
#  'beer': 275,
#  'baby eggplants': 22,
#  'lemon slices': 103,
#  'margarine': 245,
#  'parsley flakes': 93,
#  'burgers': 20,
#  'stuffing mix': 14,
#  'whole wheat hamburger buns': 19,
#  'dried dill': 84,
#  'instant yeast': 200,
#  'hot water': 573,
#  'bone-in chicken breast halves': 34,
#  'brine': 22,
#  'grape leaves': 23,
#  'macadamia nuts': 26,
#  'green olives': 319,
#  'crumbled gorgonzola': 46,
#  'bows': 7,
#  'boneless chicken thigh fillets': 5,
#  'spanish onion': 389,
#  'nonfat yogurt': 63,
#  'Betty Crocker™ oatmeal cookie mix': 2,
#  'Yoplait® Greek blackberry pie yogurt': 2,
#  'blackberries': 129,
#  'roma tomatoes': 585,
#  'sun-dried tomatoes oil': 88,
#  'whole wheat pasta': 26,
#  'peppercorns': 255,
#  'vine ripened tomatoes': 67,
#  'pork tenderloin': 369,
#  'pitted olives': 65,
#  'salt pork': 39,
#  'jalapeno chilies': 3203,
#  'vegetables': 468,
#  'long-grain rice': 497,
#  'saffron threads': 486,
#  'vegetable oil cooking spray': 267,
#  'phyllo pastry': 51,
#  'slivered almonds': 307,
#  'marjoram': 227,
#  'canned tomatoes': 129,
#  'shrimp': 2916,
#  'potatoes': 1815,
#  'white wine': 685,
#  'lemon pepper': 65,
#  'italian salad dressing': 238,
#  'whole wheat pastry flour': 58,
#  'canned coconut milk': 14,
#  'soy sauce': 9926,
#  'clarified butter': 87,
#  'mayonnaise': 880,
#  'orange zest': 282,
#  'orange juice': 906,
#  'pita wedges': 6,
#  'swordfish steaks': 22,
#  'onion flakes': 44,
#  'pure vanilla extract': 320,
#  'sour cherries': 13,
#  'farro': 50,
#  'ricotta cheese': 557,
#  'meat': 368,
#  'manchego cheese': 152,
#  'cherries': 98,
#  'mozzarella cheese': 1888,
#  'leeks': 620,
#  'cold water': 852,
#  'grated orange peel': 101,
#  'semolina flour': 70,
#  'beef stock': 299,
#  'rub': 41,
#  'lamb loin chops': 23,
#  'shortening': 267,
#  'sesame seeds': 2158,
#  'hummus': 139,
#  'cod': 70,
#  'elbow macaroni': 160,
#  'pearl barley': 40,
#  'mixed nuts': 11,
#  'tenderloin': 7,
#  'white pepper': 1897,
#  'filet': 64,
#  'sherry vinegar': 393,
#  "i can't believ it' butter! made with olive oil spread": 4,
#  'prebaked pizza crusts': 18,
#  'dri oregano leaves, crush': 28,
#  'spinach leaves, rins pat dry': 1,
#  'carrots': 5522,
#  'fatfree lowsodium chicken broth': 10,
#  'chocolate spread': 4,
#  'roasted hazelnuts': 29,
#  'roasted pistachios': 10,
#  'crushed garlic': 205,
#  'bread dough': 38,
#  'pork tenderloin medallions': 1,
#  'chilegarlic sauce': 13,
#  'sauce': 921,
#  'hot red pepper flakes': 209,
#  'butter cooking spray': 16,
#  'tomato purée': 411,
#  'flour': 2617,
#  'radicchio': 72,
#  'olive oil flavored cooking spray': 47,
#  'fillet red snapper': 45,
#  'spearmint': 8,
#  'sage leaves': 153,
#  'dried fig': 27,
#  'prosciutto': 373,
#  'hothouse cucumber': 82,
#  'chevre': 26,
#  'angel hair': 137,
#  'low-fat plain yogurt': 78,
#  'kalamata olive halves': 8,
#  'orange flower water': 44,
#  'pitted date': 42,
#  'plain dry bread crumb': 20,
#  'kasseri': 8,
#  'garlic, chop': 30,
#  'golden beets': 8,
#  'Spike Seasoning': 24,
#  'red wine vinaigrette': 5,
#  'frozen basil': 4,
#  'beans': 191,
#  'roasted tomatoes': 138,
#  'pomegranate seeds': 62,
#  'brine-cured black olives': 20,
#  'filo dough': 9,
#  'Cavenders Greek Seasoning': 1,
#  'great northern beans': 73,
#  'rotini': 125,
#  'beef bouillon powder': 3,
#  'frozen shelled edamame': 41,
#  'grated jack cheese': 58,
#  'black-eyed peas': 172,
#  'peperoncini': 22,
#  'seedless cucumber': 117,
#  'grapes': 46,
#  'apples': 348,
#  'quick-cooking oats': 26,
#  'tuna steaks': 61,
#  'coconut oil': 874,
#  'fingerling potatoes': 41,
#  'celery ribs': 659,
#  'lavender': 13,
#  'sirloin': 126,
#  'reduced fat milk': 82,
#  'vidalia onion': 149,
#  'monkfish fillets': 7,
#  'chardonnay': 15,
#  'chiles': 466,
#  'elbow pasta': 5,
#  'goat milk feta': 1,
#  'deveined shrimp': 108,
#  'boiling potatoes': 115,
#  'shell pasta': 15,
#  'spinach leaves': 177,
#  'brine-cured olives': 18,
#  'apple cider vinegar': 565,
#  'raisins': 545,
#  'penne': 136,
#  'canned low sodium chicken broth': 96,
#  'frozen peas': 845,
#  'boneless, chicken breast': 34,
#  'rocket leaves': 63,
#  'pink peppercorns': 16,
#  'shelled pistachios': 22,
#  'ricotta salata': 28,
#  'pears': 141,
#  'dry bread crumbs': 342,
#  'fennel': 188,
#  'romano cheese': 140,
#  'bread ciabatta': 21,
#  'romaine lettuce leaves': 78,
#  'chunk tuna water': 7,
#  'chicken bouillon granules': 65,
#  'Greek dressing': 19,
#  'rapid rise yeast': 23,
#  'bread flour': 361,
#  'Homemade Yogurt': 5,
#  'cheese cubes': 9,
#  'fillets': 103,
#  'yukon gold potatoes': 354,
#  'pepperoncini': 100,
#  'chicken leg quarters': 43,
#  'frozen edamame beans': 45,
#  'string beans': 24,
#  'graham crackers': 39,
#  'rusk': 4,
#  'lowfat plain greekstyl yogurt': 1,
#  'berries': 104,
#  'deli ham': 37,
#  'graviera': 3,
#  'center loin pork chop': 16,
#  'chicken breast': 59,
#  'shrimp heads': 9,
#  'ouzo': 14,
#  'balsamic vinaigrette': 23,
#  'baguette': 525,
#  'hungarian paprika': 40,
#  'white vermouth': 5,
#  'chicken meat': 94,
#  'chicken bouillon': 117,
#  'peppermint': 8,
#  'lime juice': 4521,
#  'halibut fillets': 95,
#  'chicken legs': 189,
#  'round': 57,
#  'sandwich buns': 15,
#  'halibut': 37,
#  'broth': 192,
#  'roast red peppers, drain': 46,
#  'pickled vegetables': 30,
#  'avocado': 2892,
#  'strawberries': 563,
#  'butter beans': 39,
#  'portabello mushroom': 118,
#  'stewed tomatoes': 237,
#  'dried lentils': 53,
#  'golden zucchini': 13,
#  'artichokes': 125,
#  'zest': 46,
#  'new potatoes': 120,
#  'croutons': 82,
#  'bechamel': 15,
#  'aleppo': 4,
#  'idaho potatoes': 31,
#  'ras el hanout': 39,
#  'baby greens': 27,
#  'french baguette': 118,
#  'sunflower seeds': 41,
#  'shrimp uncook': 34,
#  'italian plum tomatoes': 45,
#  'ricotta': 151,
#  'Italian bread': 226,
#  'ammonium bicarbonate': 3,
#  'half & half': 506,
#  'macaroni': 65,
#  'dry vermouth': 49,
#  'brown shrimp': 8,
#  'linguine': 327,
#  'summer squash': 29,
#  'medium-grain rice': 53,
#  'mustard powder': 90,
#  'hot pepper sauce': 331,
#  'havarti cheese': 15,
#  'herbs': 323,
#  'yellow split peas': 50,
#  'California bay leaves': 50,
#  'port wine': 20,
#  'quinces': 13,
#  'pimento stuffed green olives': 61,
#  'okra': 246,
#  'dried onion': 52,
#  'unsweetened cocoa powder': 348,
#  'mini chocolate chips': 42,
#  'red chili': 65,
#  'seasoning salt': 208,
#  'frozen pizza dough': 8,
#  'fat': 174,
#  'lamb steaks': 2,
#  'pita pockets': 14,
#  'rice vinegar': 3206,
#  'French bread loaves': 26,
#  "Uncle Ben's Original Converted Brand rice": 6,
#  'whole milk yoghurt': 53,
#  'european cucumber': 14,
#  'broccoli': 637,
#  'oil cured olives': 12,
#  'cocoa powder': 178,
#  'white chocolate chips': 28,
#  'semi-sweet chocolate morsels': 140,
#  'cremini mushrooms': 228,
#  'parsley sprigs': 143,
#  'coriander': 3048,
#  'lime zest': 284,
#  'sunflower oil': 208,
#  'cilantro': 9313,
#  'Meyer lemon juice': 24,
#  'rotisserie chicken': 166,
#  'low sodium chicken broth': 705,
#  'veal': 91,
#  'roast turkey': 13,
#  'whole wheat breadcrumbs': 48,
#  'serrano': 55,
#  'jumbo shrimp': 110,
#  'chile pepper': 489,
#  'squid': 130,
#  'basil dried leaves': 31,
#  'fronds': 35,
#  'mixed greens': 57,
#  'shank half': 1,
#  'green peas': 361,
#  'lime': 3584,
#  'olive oil spray': 63,
#  'beef sirloin': 75,
#  'low-fat white sauce': 1,
#  'cake flour': 233,
#  'pizza shells': 4,
#  'Mazola Canola Oil': 1,
#  'flour tortillas': 1446,
#  'chicken tenderloin': 62,
#  'bow-tie pasta': 159,
#  'agave nectar': 275,
#  'tarragon': 225,
#  'all potato purpos': 4,
#  'chocolate syrup': 33,
#  'wine': 129,
#  'lamb stew meat': 23,
#  'spring water': 8,
#  'tapenade': 18,
#  'panko breadcrumbs': 1397,
#  'sweetened coconut flakes': 100,
#  'Yoplait® Greek caramel yogurt': 2,
#  'caramel topping': 9,
#  'low-fat buttermilk': 90,
#  'reduced-fat sour cream': 130,
#  'fines herbes': 8,
#  'harissa': 47,
#  'creole seasoning': 252,
#  'roast': 42,
#  'diced yellow onion': 48,
#  'cumin seed': 1893,
#  'wish bone red wine vinaigrett dress': 2,
#  'refrigerated pizza dough': 49,
#  'panko': 195,
#  'blanched almonds': 162,
#  'brandy': 234,
#  'coarse semolina': 5,
#  'anchovies': 73,
#  'juniper berries': 27,
#  'merlot': 9,
#  'raw honey': 82,
#  'dark chocolate': 137,
#  'whipped cream': 220,
#  'powdered gelatin': 16,
#  'mint sauce': 6,
#  'pearl onions': 101,
#  'lamb rib chops': 15,
#  'dried chickpeas': 50,
#  'asparagus': 479,
#  'dill tips': 17,
#  'spaghetti': 515,
#  'curly parsley': 8,
#  'garlic salt': 486,
#  'salad greens': 71,
#  'reduced fat mayonnaise': 34,
#  'hot sauce': 921,
#  'pizza doughs': 208,
#  'dressing': 184,
#  'pepperoni turkei': 17,
#  'whole wheat pita bread rounds': 2,
#  'chop pecan': 26,
#  'lemon rind': 84,
#  'farmer cheese': 11,
#  'flaxseed': 54,
#  'low-fat feta': 16,
#  'boneless pork shoulder': 113,
#  'baby arugula': 96,
#  'spanish paprika': 245,
#  'beet greens': 10,
#  'anchovy fillets': 230,
#  'calamari': 33,
#  'butter-flavored spray': 2,
#  'nonstick spray': 153,
#  'uncooked ziti': 9,
#  'triscuits': 2,
#  'pita chips': 47,
#  'crackers': 73,
#  'curd cottage cheese': 24,
#  'navy beans': 32,
#  'tortillas': 406,
#  'swiss cheese': 213,
#  'littleneck clams': 99,
#  'clam juice': 109,
#  'lamb loin': 6,
#  'low sodium soy sauce': 1016,
#  'turmeric': 3030,
#  'nonfat dry milk': 13,
#  'candied cherries': 8,
#  'white sandwich bread': 75,
#  'roe': 10,
#  'baby zucchini': 14,
#  'beets': 147,
#  'crumbled blue cheese': 54,
#  'red chili peppers': 1628,
#  'worcestershire sauce': 996,
#  'chili sauce': 409,
#  'prepared horseradish': 85,
#  'mild olive oil': 45,
#  'watercress': 141,
#  'pine nuts': 78,
#  'borage': 2,
#  'pitted green olives': 72,
#  'grated orange': 203,
#  'orange rind': 48,
#  'Greek black olives': 2,
#  'base': 65,
#  'lamb rib roast': 1,
#  'sweet potatoes': 714,
#  'mustard greens': 71,
#  'pasta sauce': 447,
#  'prepared pizza crust': 5,
#  'black lentil': 15,
#  'challa': 71,
#  'Knorr® Vegetable recipe mix': 6,
#  'water chestnuts': 472,
#  "hellmann' best food mayonnais": 22,
#  'frozen spinach, thawed squeezed dry': 24,
#  'lamb stock': 22,
#  'anise seed': 77,
#  'noodles': 491,
#  'tuna water': 12,
#  'butter lettuce': 106,
#  'crimini mushrooms': 134,
#  'whole wheat tortillas': 185,
#  'tempeh': 49,
#  'yeast': 228,
#  'grill seasoning': 14,
#  'powdered sugar': 1146,
#  'hot cherry pepper': 6,
#  'pesto': 200,
#  'malt vinegar': 60,
#  'tentacles': 18,
#  'whole wheat rotini pasta': 4,
#  'cannellini beans': 310,
#  'nonfat yogurt plain': 44,
#  'lamb fillet': 7,
#  'low-fat yogurt': 37,
#  'beef bouillon': 49,
#  'green leaf lettuce': 48,
#  'vine leaves': 5,
#  'pointed peppers': 1,
#  'mahimahi': 5,
#  'hearts of romaine': 28,
#  'banana peppers': 57,
#  'lamb leg': 15,
#  'parsnips': 79,
#  'canola mayonnaise': 13,
#  'nonfat buttermilk': 12,
#  'vanilla beans': 318,
#  'apricots': 48,
#  'grated parmesan': 149,
#  'tortellini': 44,
#  'cod fillets': 92,
#  'potato rolls': 3,
#  'raspberry vinegar': 10,
#  'diced celery': 105,
#  'corn oil': 172,
#  'superfine sugar': 125,
#  'slab bacon': 21,
#  'pork shoulder': 213,
#  'mashed potatoes': 94,
#  'baking spray': 16,
#  'cheese spread': 13,
#  'clementines': 13,
#  'spices': 298,
#  'cornish game hens': 15,
#  'pure vanilla': 10,
#  'boneless chicken': 192,
#  'pocket bread': 2,
#  'bamboo shoots': 372,
#  'hot pepper rings': 6,
#  'unsalted pistachios': 20,
#  'dried apple rings': 1,
#  'buttermilk': 857,
#  'sweet pepper': 175,
#  'flat leaf spinach': 13,
#  'frozen green beans': 24,
#  'beef stock cubes': 38,
#  'Swerve Sweetener': 13,
#  'lowfat greek yogurt': 38,
#  'passata': 24,
#  'zesty italian dressing': 46,
#  'chili powder': 4130,
#  'cilantro sprigs': 274,
#  'vanilla bean paste': 66,
#  'stevia extract': 13,
#  'tilapia fillets': 113,
#  'mushroom caps': 49,
#  'watermelon seeds': 2,
#  'flavored oil': 27,
#  'pickled beets': 5,
#  'salad': 177,
#  'natural pistachios': 8,
#  'syrup': 85,
#  'dried apricot': 127,
#  'double-acting baking powder': 21,
#  'boneless chicken cutlet': 9,
#  'egg noodles': 218,
#  'chicken drumsticks': 199,
#  'Country Crock® Spread': 37,
#  'currant': 49,
#  'canned chicken broth': 31,
#  'Mezzetta Sliced Greek Kalamata Olives': 2,
#  'poblano chiles': 191,
#  'hard-boiled egg': 190,
#  'bibb lettuce': 31,
#  'pastry': 57,
#  'white onion': 1247,
#  'pickling spices': 21,
#  'olive oil cooking spray': 62,
#  'cooking oil': 977,
#  'tart shells': 11,
#  'Tabasco Pepper Sauce': 230,
#  'dried red chile peppers': 210,
#  'alfalfa sprouts': 12,
#  'whole wheat pita pockets': 7,
#  'nonfat ricotta cheese': 43,
#  'garlic puree': 47,
#  'condensed cream of chicken soup': 77,
#  'asian eggplants': 32,
#  'bourbon whiskey': 190,
#  'maple syrup': 584,
#  'bacon': 970,
#  'dates': 105,
#  'green cabbage': 338,
#  'dried mixed herbs': 14,
#  'yellow peppers': 144,
#  'roasted garlic': 48,
#  'dried sage': 73,
#  'red swiss chard': 6,
#  'wheat': 74,
#  'halloumi cheese': 5,
#  'cutlet': 29,
#  'wheat germ': 18,
#  'pork sirloin chops': 4,
#  'mahlab': 1,
#  'candy': 26,
#  'sherry wine vinegar': 61,
#  'spaghetti squash': 93,
#  'burger buns': 39,
#  'Italian parsley leaves': 205,
#  'celery stick': 17,
#  'egg': 53,
#  'instant rice': 61,
#  'tangerine juice': 14,
#  'chestnuts': 49,
#  'breakfast sausages': 43,
#  'lima beans': 39,
#  'marinara sauce': 510,
#  'thin pizza crust': 22,
#  'cream': 586,
#  'whole almonds': 37,
#  'country bread': 94,
#  'reduced-fat milk': 136,
#  'farina': 4,
#  'picholine olives': 12,
#  'fusilli': 65,
#  'sundried tomato pesto': 21,
#  'sunflower kernels': 4,
#  'rib eye steaks': 62,
#  'whole wheat penne pasta': 8,
#  'sugar pea': 274,
#  'field lettuce': 10,
#  'new york strip steaks': 31,
#  'persian cucumber': 86,
#  'lemon peel': 68,
#  'dandelion greens': 13,
#  'escarole': 81,
#  "hellmann' best food real mayonnais": 74,
#  'Lipton® Recipe Secrets® Onion Soup Mix': 8,
#  'dri leav rosemari': 8,
#  'dried leaves oregano': 52,
#  'Italian breadcrumbs': 163,
#  'chuck': 170,
#  'snappers': 14,
#  'medjool date': 35,
#  'cardamom seeds': 64,
#  'sage': 287,
#  'beef stew meat': 70,
#  'sea scallops': 151,
#  'filo': 4,
#  'rose water': 36,
#  'ketchup': 901,
#  'whole grain mustard': 71,
#  'glaze': 50,
#  'chili pepper': 332,
#  'all purpose unbleached flour': 162,
#  'star anise': 611,
#  'green lentil': 49,
#  'round loaf': 8,
#  'calamata olives': 15,
#  'rib': 87,
#  'orange peel': 61,
#  'chicken breast tenders': 61,
#  'yellow squash': 167,
#  'long-grain brown rice': 12,
#  'frozen blueberries': 80,
#  'bread slices': 48,
#  'black peppercorns': 678,
#  'lentils': 151,
#  'whole allspice': 24,
#  'tuna olive oil': 44,
#  'coriander seeds': 683,
#  'sausages': 251,
#  'sourdough bread': 101,
#  'white kidney beans': 21,
#  'Monterey Jack cheese': 458,
#  'free-range eggs': 17,
#  'low-fat plain greek yogurt': 12,
#  'nuts': 117,
#  'Cholula Hot Sauce': 10,
#  'flax seeds': 17,
#  'pickle relish': 30,
#  'italian seasoning mix': 7,
#  'red mullet': 2,
#  'grape vine leaves': 1,
#  'italian tomatoes': 42,
#  'pita wraps': 1,
#  'pumpkin': 135,
#  'chili flakes': 405,
#  'spring roll wrappers': 91,
#  'salmon fillets': 356,
#  'liquid honey': 15,
#  'baby back ribs': 47,
#  'low-fat caesar dressing': 1,
#  'sprinkles': 78,
#  'mahimahi fillet': 2,
#  'vinaigrette': 80,
#  'tomato juice': 146,
#  'bone skin on chicken thigh': 16,
#  'nonfat milk': 42,
#  'bottled clam juice': 52,
#  'prawns': 230,
#  ...}

# %%
MIN_FREQUENCY = 10
filtered_ingredients = {k: v for k, v in ingredients.items() if v >= MIN_FREQUENCY}

# %%
filtered_ingredients.keys()
# Out:
# dict_keys(['romaine lettuce', 'black olives', 'grape tomatoes', 'garlic', 'pepper', 'purple onion', 'seasoning', 'garbanzo beans', 'feta cheese crumbles', 'pork', 'finely parsley', 'onions', 'salt', 'vinegar', 'dried oregano', 'red wine vinegar', 'olive oil', 'boneless chop pork', 'lemon juice', 'orange', 'anise', 'cinnamon sticks', 'unflavored gelatin', 'zinfandel', 'orange blossom honey', 'sugar', 'lemon', 'calimyrna figs', '', 'honey', 'whipping cream', 'plain whole-milk yogurt', 'dill', 'yoghurt', 'eggs', 'cheese', 'feta cheese', 'phyllo', 'kefalotyri', 'black pepper', 'extra-virgin olive oil', 'hamburger buns', 'paprika', 'mint', 'cinnamon', 'balsamic vinegar', 'baby spinach leaves', 'lamb', 'dried mint flakes', 'tomatoes', 'dried dillweed', 'red wine', 'plain yogurt', 'pita bread rounds', 'cucumber', 'liquid', 'tahini', 'dry red wine', 'Turkish bay leaves', 'oregano', 'octopuses', 'mint leaves', 'almonds', 'kosher salt', 'greek yogurt', 'cracked black pepper', 'english cucumber', 'shallots', 'white vinegar', 'water', 'dried currants', 'swiss chard', 'eggplant', 'grated parmesan cheese', 'plain breadcrumbs', 'egg yolks', 'diced tomatoes', 'all-purpose flour', 'bay leaf', 'tomato paste', 'unsalted butter', 'allspice', 'milk', 'grated nutmeg', 'juice', 'green pepper', 'capers', 'vinaigrette dressing', 'kalamata', 'parsley', 'rosemary', 'thyme leaves', 'yellow bell pepper', 'fat skimmed chicken broth', 'couscous', 'greek seasoning', 'brown rice', 'chicken stock', 'red bell pepper', 'whole milk', 'bread crumb', 'parmigiano reggiano cheese', 'thyme sprigs', 'ziti', 'heavy cream', 'puff pastry', 'flour for dusting', 'dry white wine', 'leaf parsley', 'mussels', 'Greek feta', 'chicken thighs', 'sweet paprika', 'bay leaves', 'pitted prunes', 'cherry tomatoes', 'sea salt', 'white wine vinegar', 'quinoa', 'italian seasoning', 'baby spinach', 'crushed red pepper', 'walnuts', 'vanilla', 'kale', 'rosemary sprigs', 'fat less sodium chicken broth', 'white bread', 'pitted kalamata olives', 'cooking spray', 'boneless chicken breast halves', 'cayenne pepper', 'warm water', 'chickpeas', 'tahini paste', 'coarse salt', 'boiling water', 'pinenuts', 'roasted red peppers', 'red pepper flakes', 'yellow onion', 'beef', 'dill weed', 'nutmeg', 'sour cream', 'grated lemon zest', 'unsalted chicken stock', 'crushed tomatoes', 'oven-ready lasagna noodles', 'onion', 'part-skim ricotta cheese', 'flat leaf parsley', 'oregano leaves', 'boneless chicken breasts', 'marinade', 'oil', 'chicken', 'plain low-fat yogurt', 'baking potatoes', 'low-fat milk', 'sharp cheddar cheese', 'aleppo pepper', 'green bell pepper', 'turkey', 'garlic powder', 'cumin', 'yellow mustard', 'tomato sauce', 'dried basil', 'crushed red pepper flakes', 'lamb shoulder', 'tomatoes with juice', 'bulgur', 'frozen spinach', 'part-skim mozzarella cheese', 'fat milk', 'baking powder', 'vine tomatoes', 'leg of lamb', 'egg substitute', 'corn starch', 'bulgur wheat', 'parmesan cheese', 'chicken breasts', 'nonfat greek yogurt', 'fat yogurt', 'dried rosemary', 'cottage cheese', 'butter', 'phyllo dough', 'tzatziki', 'pita bread', 'greek plain yogurt', 'boneless lamb', 'button mushrooms', 'vegetable stock', 'brown lentils', 'zucchini', 'herbes de provence', 'goat cheese', 'dijon mustard', 'frisee', 'red pepper', 'broccoli florets', 'Wish-Bone Italian Dressing', 'vanilla extract', 'almond extract', 'confectioners sugar', 'white sugar', 'iceberg lettuce', 'beefsteak tomatoes', 'rice', 'chicken broth', 'whole chicken', 'orzo pasta', 'russet potatoes', 'coarse kosher salt', 'beef broth', 'brown sugar', 'pumpkin purée', 'baking soda', 'whole wheat flour', 'pecans', 'bananas', 'ginger', 'vegetable broth', 'basmati rice', 'bison', 'cayenne', 'green beans', 'hearts of palm', 'greek-style vinaigrette', 'artichoke hearts', 'kalamata olives', 'flatbread', 'lemon wedge', 'spinach', 'sun-dried tomatoes', 'white rice', 'mushrooms', 'ripe olives', 'sub buns', 'Balsamico Bianco', 'lettuce leaves', 'ham', 'turkey breas ...

# %%
recipes = list(df['recipe'])
labels = list(df['cuisine'])

# %%
vectorizer = CountVectorizer(vocabulary=filtered_ingredients.keys())
vectorizer.fit(recipes)
print('Number of Features: %d'%len(vectorizer.get_feature_names()))
# Out:
# Number of Features: 3033

# %%
print(vectorizer.get_feature_names())
# Out:
# ['romaine lettuce', 'black olives', 'grape tomatoes', 'garlic', 'pepper', 'purple onion', 'seasoning', 'garbanzo beans', 'feta cheese crumbles', 'pork', 'finely parsley', 'onions', 'salt', 'vinegar', 'dried oregano', 'red wine vinegar', 'olive oil', 'boneless chop pork', 'lemon juice', 'orange', 'anise', 'cinnamon sticks', 'unflavored gelatin', 'zinfandel', 'orange blossom honey', 'sugar', 'lemon', 'calimyrna figs', '', 'honey', 'whipping cream', 'plain whole-milk yogurt', 'dill', 'yoghurt', 'eggs', 'cheese', 'feta cheese', 'phyllo', 'kefalotyri', 'black pepper', 'extra-virgin olive oil', 'hamburger buns', 'paprika', 'mint', 'cinnamon', 'balsamic vinegar', 'baby spinach leaves', 'lamb', 'dried mint flakes', 'tomatoes', 'dried dillweed', 'red wine', 'plain yogurt', 'pita bread rounds', 'cucumber', 'liquid', 'tahini', 'dry red wine', 'Turkish bay leaves', 'oregano', 'octopuses', 'mint leaves', 'almonds', 'kosher salt', 'greek yogurt', 'cracked black pepper', 'english cucumber', 'shallots', 'white vinegar', 'water', 'dried currants', 'swiss chard', 'eggplant', 'grated parmesan cheese', 'plain breadcrumbs', 'egg yolks', 'diced tomatoes', 'all-purpose flour', 'bay leaf', 'tomato paste', 'unsalted butter', 'allspice', 'milk', 'grated nutmeg', 'juice', 'green pepper', 'capers', 'vinaigrette dressing', 'kalamata', 'parsley', 'rosemary', 'thyme leaves', 'yellow bell pepper', 'fat skimmed chicken broth', 'couscous', 'greek seasoning', 'brown rice', 'chicken stock', 'red bell pepper', 'whole milk', 'bread crumb', 'parmigiano reggiano cheese', 'thyme sprigs', 'ziti', 'heavy cream', 'puff pastry', 'flour for dusting', 'dry white wine', 'leaf parsley', 'mussels', 'Greek feta', 'chicken thighs', 'sweet paprika', 'bay leaves', 'pitted prunes', 'cherry tomatoes', 'sea salt', 'white wine vinegar', 'quinoa', 'italian seasoning', 'baby spinach', 'crushed red pepper', 'walnuts', 'vanilla', 'kale', 'rosemary sprigs', 'fat less sodium chicken broth', 'white bread', 'pitted kalamata olives', 'cooking spray', 'boneless chicken breast halves', 'cayenne pepper', 'warm water', 'chickpeas', 'tahini paste', 'coarse salt', 'boiling water', 'pinenuts', 'roasted red peppers', 'red pepper flakes', 'yellow onion', 'beef', 'dill weed', 'nutmeg', 'sour cream', 'grated lemon zest', 'unsalted chicken stock', 'crushed tomatoes', 'oven-ready lasagna noodles', 'onion', 'part-skim ricotta cheese', 'flat leaf parsley', 'oregano leaves', 'boneless chicken breasts', 'marinade', 'oil', 'chicken', 'plain low-fat yogurt', 'baking potatoes', 'low-fat milk', 'sharp cheddar cheese', 'aleppo pepper', 'green bell pepper', 'turkey', 'garlic powder', 'cumin', 'yellow mustard', 'tomato sauce', 'dried basil', 'crushed red pepper flakes', 'lamb shoulder', 'tomatoes with juice', 'bulgur', 'frozen spinach', 'part-skim mozzarella cheese', 'fat milk', 'baking powder', 'vine tomatoes', 'leg of lamb', 'egg substitute', 'corn starch', 'bulgur wheat', 'parmesan cheese', 'chicken breasts', 'nonfat greek yogurt', 'fat yogurt', 'dried rosemary', 'cottage cheese', 'butter', 'phyllo dough', 'tzatziki', 'pita bread', 'greek plain yogurt', 'boneless lamb', 'button mushrooms', 'vegetable stock', 'brown lentils', 'zucchini', 'herbes de provence', 'goat cheese', 'dijon mustard', 'frisee', 'red pepper', 'broccoli florets', 'Wish-Bone Italian Dressing', 'vanilla extract', 'almond extract', 'confectioners sugar', 'white sugar', 'iceberg lettuce', 'beefsteak tomatoes', 'rice', 'chicken broth', 'whole chicken', 'orzo pasta', 'russet potatoes', 'coarse kosher salt', 'beef broth', 'brown sugar', 'pumpkin purée', 'baking soda', 'whole wheat flour', 'pecans', 'bananas', 'ginger', 'vegetable broth', 'basmati rice', 'bison', 'cayenne', 'green beans', 'hearts of palm', 'greek-style vinaigrette', 'artichoke hearts', 'kalamata olives', 'flatbread', 'lemon wedge', 'spinach', 'sun-dried tomatoes', 'white rice', 'mushrooms', 'ripe olives', 'sub buns', 'Balsamico Bianco', 'lettuce leaves', 'ham', 'turkey breast', 'chedd ...

# %%
X_train = vectorizer.transform(recipes).toarray()
Y_train = labels

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()
clf.fit(X_train, Y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
input_recipe = input("What is your recipe? \n> ")
while input_recipe != 'quit':
    input_recipe = input_recipe.lower()
    X_input = vectorizer.transform([input_recipe]).toarray()
    prediction = clf.predict(X_input)[0]
    
    print('\nIdentified Ingredients: \n> %s'%vectorizer.inverse_transform(X_input))
    
    print('\nPredicted Cuisine Type: \n> %s'%prediction)
    print('\n====================================')
    
    input_recipe = input("What is your recipe? \n> ")
# Out:
# What is your recipe?
# > salmon
#
# Identified Ingredients:
# > [array(['salmon'], dtype='<U72')]
#
# Predicted Cuisine Type:
# > japanese
#
# ====================================
# What is your recipe?
# > quit

# %%
clf.classes_
# Out:
# array(['brazilian', 'british', 'cajun_creole', 'chinese', 'filipino',
#        'french', 'greek', 'indian', 'irish', 'italian', 'jamaican',
#        'japanese', 'korean', 'mexican', 'moroccan', 'russian',
#        'southern_us', 'spanish', 'thai', 'vietnamese'], dtype='<U12')

# %%
input_recipe = input("What is your recipe? \n> ")
input_recipe = input_recipe.lower()
X_input = vectorizer.transform([input_recipe]).toarray()
prob = clf.predict_proba(X_input)[0]
classes = clf.classes_

print('\nIdentified Ingredients: \n> %s'%vectorizer.inverse_transform(X_input))

print('\nCuisine Probabilities:')
for i in range(len(prob)):
    print('> %s: %s%%'%(classes[i], int(prob[i]*100)))
# Out:
# What is your recipe?
# > 1 cup plain Greek yogurt or sour cream Juice of 1 Lime plus more for garnish 1 cup fresh cilantro leaves and stems 1 finely chopped green onions (aka scallions) plus more for garnish kosher salt 3 pounds bone-in chicken breast or thigh pieces 3 dried chile de arbol 8 garlic cloves divided 2 bay leaves 2 teaspoons black peppercorns 2 tablespoons coconut, grapeseed, or peanut oil 1 tablespoon unsalted butter 1/2 medium red onion finely chopped 1 red, orange, or yellow bell pepper finely chopped 1 inch piece fresh ginger peeled and grated 3/4 teaspoon smoked paprika 1/2 cup freshly squeezed lime juice 1/3 cup 100% pure pineapple juice 1/4 cup red wine vinegar 1/4 cup low-sodium soy sauce 1 to 2 serrano or Thai chile  sliced and seeded (if desired), optional Sambal or Chile-garlic sauce for serving 10 corn tortillas
#
# Identified Ingredients:
# > [array(['black', 'bone', 'butter', 'chicken', 'chile', 'cilantro',
#        'coconut', 'corn', 'cream', 'garlic', 'ginger', 'greek', 'juice',
#        'leaves', 'lime', 'low', 'medium', 'oil', 'onion', 'onions',
#        'orange', 'paprika', 'peanut', 'pepper', 'peppercorns',
#        'pineapple', 'red', 'salt', 'sauce', 'scallions', 'serrano', 'soy',
#        'tortillas', 'vinegar', 'wine'], dtype='<U72')]
#
# Cuisine Probabilities:
# > brazilian: 0%
# > british: 0%
# > cajun_creole: 0%
# > chinese: 0%
# > filipino: 8%
# > french: 0%
# > greek: 0%
# > indian: 0%
# > irish: 0%
# > italian: 0%
# > jamaican: 0%
# > japanese: 0%
# > korean: 0%
# > mexican: 54%
# > moroccan: 0%
# > russian: 0%
# > southern_us: 0%
# > spanish: 0%
# > thai: 36%
# > vietnamese: 0%

# %%
from sklearn.pipeline import Pipeline
LogReg_model = Pipeline([('vectorizer', vectorizer),('NB', clf)])

# %%
import pickle
filename = 'LogReg_v1.sav'
pickle.dump(LogReg_model, open(filename,'wb'))

# %%
LogReg_model.predict(list(['hi', 'hi']))
# Out:
# array(['italian', 'italian'], dtype='<U12')
