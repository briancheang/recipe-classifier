# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
df = pd.read_json('../../data/train/trainText-75-25.json', lines=True)

# %%
df.head()
# Out:
#   cuisine     id                                        ingredients  \
# 0   greek  10259  [romaine lettuce, black olives, grape tomatoes...
# 1   greek  34471  [ground pork, finely chopped fresh parsley, on...
# 2   greek   4635  [minced garlic, dried oregano, red wine vinega...
# 3   greek   5980  [orange, anise, cinnamon sticks, unflavored ge...
# 4   greek  18031  [fresh dill, yoghurt, salt, myzithra, large eg...
#
#                                  ingredientsFiltered  label  \
# 0  [romaine lettuce, black olives, grape tomatoes...      0
# 1  [pork, finely parsley, onions, salt, vinegar, ...      0
# 2  [garlic, dried oregano, red wine vinegar, oliv...      0
# 3  [orange, anise, cinnamon sticks, unflavored ge...      0
# 4  [dill, yoghurt, salt, myzithra, eggs, cheese, ...      0
#
#                                               recipe
# 0  romaine lettuce black_olives grape_tomatoes ga...
# 1   pork finely_parsley onions salt vinegar caul_fat
# 2  garlic dried_oregano red_wine_vinegar olive_oi...
# 3  orange anise cinnamon_sticks unflavored_gelati...
# 4  dill yoghurt salt myzithra eggs cheese feta_ch...

# %%
ingredients = {}
for lst in df['ingredientsFiltered']:
    for i in lst:
        if not i in ingredients:
            ingredients[i] = 1
        else:
            ingredients[i] += 1

# %%
MIN_FREQUENCY = 10
filtered_ingredients = {k: v for k, v in ingredients.items() if v >= MIN_FREQUENCY}

# %%
filtered_ingredients.keys()
# Out:
# dict_keys(['romaine lettuce', 'black olives', 'grape tomatoes', 'garlic', 'pepper', 'purple onion', 'seasoning', 'garbanzo beans', 'feta cheese crumbles', 'pork', 'finely parsley', 'onions', 'salt', 'vinegar', 'dried oregano', 'red wine vinegar', 'olive oil', 'boneless chop pork', 'lemon juice', 'orange', 'anise', 'cinnamon sticks', 'unflavored gelatin', 'zinfandel', 'orange blossom honey', 'sugar', 'lemon', 'calimyrna figs', '', 'honey', 'whipping cream', 'plain whole-milk yogurt', 'dill', 'yoghurt', 'eggs', 'cheese', 'feta cheese', 'phyllo', 'kefalotyri', 'black pepper', 'extra-virgin olive oil', 'hamburger buns', 'paprika', 'mint', 'cinnamon', 'balsamic vinegar', 'baby spinach leaves', 'lamb', 'dried mint flakes', 'tomatoes', 'dried dillweed', 'red wine', 'plain yogurt', 'pita bread rounds', 'cucumber', 'liquid', 'tahini', 'dry red wine', 'Turkish bay leaves', 'oregano', 'octopuses', 'mint leaves', 'almonds', 'kosher salt', 'greek yogurt', 'cracked black pepper', 'english cucumber', 'shallots', 'white vinegar', 'water', 'dried currants', 'swiss chard', 'eggplant', 'grated parmesan cheese', 'plain breadcrumbs', 'egg yolks', 'diced tomatoes', 'all-purpose flour', 'bay leaf', 'tomato paste', 'unsalted butter', 'allspice', 'milk', 'grated nutmeg', 'juice', 'green pepper', 'capers', 'vinaigrette dressing', 'kalamata', 'parsley', 'rosemary', 'thyme leaves', 'yellow bell pepper', 'fat skimmed chicken broth', 'couscous', 'greek seasoning', 'brown rice', 'chicken stock', 'red bell pepper', 'whole milk', 'bread crumb', 'parmigiano reggiano cheese', 'thyme sprigs', 'ziti', 'heavy cream', 'puff pastry', 'flour for dusting', 'dry white wine', 'leaf parsley', 'mussels', 'Greek feta', 'chicken thighs', 'sweet paprika', 'bay leaves', 'pitted prunes', 'cherry tomatoes', 'sea salt', 'white wine vinegar', 'quinoa', 'italian seasoning', 'baby spinach', 'crushed red pepper', 'walnuts', 'vanilla', 'kale', 'rosemary sprigs', 'fat less sodium chicken broth', 'white bread', 'pitted kalamata olives', 'cooking spray', 'boneless chicken breast halves', 'cayenne pepper', 'warm water', 'chickpeas', 'tahini paste', 'coarse salt', 'boiling water', 'pinenuts', 'roasted red peppers', 'red pepper flakes', 'yellow onion', 'beef', 'dill weed', 'nutmeg', 'sour cream', 'grated lemon zest', 'unsalted chicken stock', 'crushed tomatoes', 'oven-ready lasagna noodles', 'onion', 'part-skim ricotta cheese', 'flat leaf parsley', 'oregano leaves', 'boneless chicken breasts', 'marinade', 'oil', 'chicken', 'plain low-fat yogurt', 'baking potatoes', 'low-fat milk', 'sharp cheddar cheese', 'aleppo pepper', 'green bell pepper', 'turkey', 'garlic powder', 'cumin', 'yellow mustard', 'tomato sauce', 'dried basil', 'crushed red pepper flakes', 'lamb shoulder', 'tomatoes with juice', 'bulgur', 'frozen spinach', 'part-skim mozzarella cheese', 'fat milk', 'baking powder', 'vine tomatoes', 'leg of lamb', 'egg substitute', 'corn starch', 'bulgur wheat', 'parmesan cheese', 'chicken breasts', 'nonfat greek yogurt', 'fat yogurt', 'dried rosemary', 'cottage cheese', 'butter', 'phyllo dough', 'tzatziki', 'pita bread', 'greek plain yogurt', 'boneless lamb', 'button mushrooms', 'vegetable stock', 'brown lentils', 'zucchini', 'herbes de provence', 'goat cheese', 'dijon mustard', 'frisee', 'red pepper', 'broccoli florets', 'Wish-Bone Italian Dressing', 'vanilla extract', 'almond extract', 'confectioners sugar', 'white sugar', 'iceberg lettuce', 'beefsteak tomatoes', 'rice', 'chicken broth', 'whole chicken', 'orzo pasta', 'russet potatoes', 'coarse kosher salt', 'beef broth', 'brown sugar', 'pumpkin purée', 'baking soda', 'whole wheat flour', 'pecans', 'bananas', 'ginger', 'vegetable broth', 'basmati rice', 'bison', 'cayenne', 'green beans', 'hearts of palm', 'greek-style vinaigrette', 'artichoke hearts', 'kalamata olives', 'flatbread', 'lemon wedge', 'spinach', 'sun-dried tomatoes', 'white rice', 'mushrooms', 'ripe olives', 'sub buns', 'Balsamico Bianco', 'lettuce leaves', 'ham', 'turkey breas ...

# %%
recipes = list(df['recipe'])
labels = list(df['cuisine'])

# %%
vectorizer = CountVectorizer(vocabulary=list(filtered_ingredients.keys()))
vectorizer.fit(recipes)
print('Number of Features: %d'%len(vectorizer.get_feature_names()))
# Out:
# Number of Features: 3033

# %%
print(vectorizer.get_feature_names())
# Out:
# ['romaine lettuce', 'black olives', 'grape tomatoes', 'garlic', 'pepper', 'purple onion', 'seasoning', 'garbanzo beans', 'feta cheese crumbles', 'pork', 'finely parsley', 'onions', 'salt', 'vinegar', 'dried oregano', 'red wine vinegar', 'olive oil', 'boneless chop pork', 'lemon juice', 'orange', 'anise', 'cinnamon sticks', 'unflavored gelatin', 'zinfandel', 'orange blossom honey', 'sugar', 'lemon', 'calimyrna figs', '', 'honey', 'whipping cream', 'plain whole-milk yogurt', 'dill', 'yoghurt', 'eggs', 'cheese', 'feta cheese', 'phyllo', 'kefalotyri', 'black pepper', 'extra-virgin olive oil', 'hamburger buns', 'paprika', 'mint', 'cinnamon', 'balsamic vinegar', 'baby spinach leaves', 'lamb', 'dried mint flakes', 'tomatoes', 'dried dillweed', 'red wine', 'plain yogurt', 'pita bread rounds', 'cucumber', 'liquid', 'tahini', 'dry red wine', 'Turkish bay leaves', 'oregano', 'octopuses', 'mint leaves', 'almonds', 'kosher salt', 'greek yogurt', 'cracked black pepper', 'english cucumber', 'shallots', 'white vinegar', 'water', 'dried currants', 'swiss chard', 'eggplant', 'grated parmesan cheese', 'plain breadcrumbs', 'egg yolks', 'diced tomatoes', 'all-purpose flour', 'bay leaf', 'tomato paste', 'unsalted butter', 'allspice', 'milk', 'grated nutmeg', 'juice', 'green pepper', 'capers', 'vinaigrette dressing', 'kalamata', 'parsley', 'rosemary', 'thyme leaves', 'yellow bell pepper', 'fat skimmed chicken broth', 'couscous', 'greek seasoning', 'brown rice', 'chicken stock', 'red bell pepper', 'whole milk', 'bread crumb', 'parmigiano reggiano cheese', 'thyme sprigs', 'ziti', 'heavy cream', 'puff pastry', 'flour for dusting', 'dry white wine', 'leaf parsley', 'mussels', 'Greek feta', 'chicken thighs', 'sweet paprika', 'bay leaves', 'pitted prunes', 'cherry tomatoes', 'sea salt', 'white wine vinegar', 'quinoa', 'italian seasoning', 'baby spinach', 'crushed red pepper', 'walnuts', 'vanilla', 'kale', 'rosemary sprigs', 'fat less sodium chicken broth', 'white bread', 'pitted kalamata olives', 'cooking spray', 'boneless chicken breast halves', 'cayenne pepper', 'warm water', 'chickpeas', 'tahini paste', 'coarse salt', 'boiling water', 'pinenuts', 'roasted red peppers', 'red pepper flakes', 'yellow onion', 'beef', 'dill weed', 'nutmeg', 'sour cream', 'grated lemon zest', 'unsalted chicken stock', 'crushed tomatoes', 'oven-ready lasagna noodles', 'onion', 'part-skim ricotta cheese', 'flat leaf parsley', 'oregano leaves', 'boneless chicken breasts', 'marinade', 'oil', 'chicken', 'plain low-fat yogurt', 'baking potatoes', 'low-fat milk', 'sharp cheddar cheese', 'aleppo pepper', 'green bell pepper', 'turkey', 'garlic powder', 'cumin', 'yellow mustard', 'tomato sauce', 'dried basil', 'crushed red pepper flakes', 'lamb shoulder', 'tomatoes with juice', 'bulgur', 'frozen spinach', 'part-skim mozzarella cheese', 'fat milk', 'baking powder', 'vine tomatoes', 'leg of lamb', 'egg substitute', 'corn starch', 'bulgur wheat', 'parmesan cheese', 'chicken breasts', 'nonfat greek yogurt', 'fat yogurt', 'dried rosemary', 'cottage cheese', 'butter', 'phyllo dough', 'tzatziki', 'pita bread', 'greek plain yogurt', 'boneless lamb', 'button mushrooms', 'vegetable stock', 'brown lentils', 'zucchini', 'herbes de provence', 'goat cheese', 'dijon mustard', 'frisee', 'red pepper', 'broccoli florets', 'Wish-Bone Italian Dressing', 'vanilla extract', 'almond extract', 'confectioners sugar', 'white sugar', 'iceberg lettuce', 'beefsteak tomatoes', 'rice', 'chicken broth', 'whole chicken', 'orzo pasta', 'russet potatoes', 'coarse kosher salt', 'beef broth', 'brown sugar', 'pumpkin purée', 'baking soda', 'whole wheat flour', 'pecans', 'bananas', 'ginger', 'vegetable broth', 'basmati rice', 'bison', 'cayenne', 'green beans', 'hearts of palm', 'greek-style vinaigrette', 'artichoke hearts', 'kalamata olives', 'flatbread', 'lemon wedge', 'spinach', 'sun-dried tomatoes', 'white rice', 'mushrooms', 'ripe olives', 'sub buns', 'Balsamico Bianco', 'lettuce leaves', 'ham', 'turkey breast', 'chedd ...

# %%
X_train = vectorizer.transform(recipes).toarray()
Y_train = labels

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()
clf.fit(X_train, Y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
from sklearn.pipeline import Pipeline
LogReg_model = Pipeline([('vectorizer', vectorizer),('NB', clf)])

# %%
import pickle
filename = 'LogReg_v2.sav'
pickle.dump(LogReg_model, open(filename,'wb'))

# %%
input_recipe = input("What is your recipe? \n> ")
while input_recipe != 'quit':
    input_recipe = input_recipe.lower()
    X_input = vectorizer.transform([input_recipe]).toarray()
    prediction = clf.predict(X_input)[0]
    
    print('\nIdentified Ingredients: \n> %s'%vectorizer.inverse_transform(X_input))
    
    print('\nPredicted Cuisine Type: \n> %s'%prediction)
    print('\n====================================')
    
    input_recipe = input("What is your recipe? \n> ")
# Out:
# What is your recipe?
# > LogReg_v1 = pickle.load(open('../models/Log_Reg_v1/LogReg_v1.sav', 'rb')) y_pred = LogReg_v1.predict(X_test) print(metrics.classification_report(y_test, y_pred))
#
# Identified Ingredients:
# > [array([], dtype='<U355')]
#
# Predicted Cuisine Type:
# > italian
#
# ====================================
# What is your recipe?
# > 1 cup plain Greek yogurt or sour cream Juice of 1 Lime plus more for garnish 1 cup fresh cilantro leaves and stems 1 finely chopped green onions (aka scallions) plus more for garnish kosher salt 3 pounds bone-in chicken breast or thigh pieces 3 dried chile de arbol 8 garlic cloves divided 2 bay leaves 2 teaspoons black peppercorns 2 tablespoons coconut, grapeseed, or peanut oil 1 tablespoon unsalted butter 1/2 medium red onion finely chopped 1 red, orange, or yellow bell pepper finely chopped 1 inch piece fresh ginger peeled and grated 3/4 teaspoon smoked paprika 1/2 cup freshly squeezed lime juice 1/3 cup 100% pure pineapple juice 1/4 cup red wine vinegar 1/4 cup low-sodium soy sauce 1 to 2 serrano or Thai chile  sliced and seeded (if desired), optional Sambal or Chile-garlic sauce for serving 10 corn tortillas
#
# Identified Ingredients:
# > [array(['garlic', 'pepper', 'onions', 'salt', 'vinegar', 'orange',
#        'paprika', 'juice', 'onion', 'oil', 'chicken', 'butter', 'ginger',
#        'scallions', 'peppercorns', 'sauce', 'cilantro', 'serrano', 'lime',
#        'wine', 'tortillas', 'cream', 'leaves', 'chile', 'pineapple',
#        'coconut', 'corn', 'red', 'soy', 'peanut'], dtype='<U355')]
#
# Predicted Cuisine Type:
# > thai
#
# ====================================
# What is your recipe?
# > quit

# %%
input_recipe = input("What is your recipe? \n> ")
input_recipe = input_recipe.lower()
X_input = vectorizer.transform([input_recipe]).toarray()
prob = clf.predict_proba(X_input)[0]
classes = clf.classes_

print('\nIdentified Ingredients: \n> %s'%vectorizer.inverse_transform(X_input))

print('\nCuisine Probabilities:')
for i in range(len(prob)):
    print('> %s: %s%%'%(classes[i], int(prob[i]*100)))
# Out:
# What is your recipe?
# > olive oil
#
# Identified Ingredients:
# > [array(['oil'], dtype='<U355')]
#
# Cuisine Probabilities:
# > brazilian: 0%
# > british: 0%
# > cajun_creole: 0%
# > chinese: 20%
# > filipino: 0%
# > french: 7%
# > greek: 6%
# > indian: 4%
# > irish: 0%
# > italian: 26%
# > jamaican: 0%
# > japanese: 5%
# > korean: 0%
# > mexican: 10%
# > moroccan: 0%
# > russian: 0%
# > southern_us: 2%
# > spanish: 6%
# > thai: 5%
# > vietnamese: 0%
